# %% [markdown]
# <a href="https://colab.research.google.com/github/sukjin1/ed/blob/main/gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 경사하강법(Gradient Descent)은 최적화 알고리즘 중 하나로, 함수의 최솟값을 찾는 방법입니다. 여기에는 목적 함수와 그래디언트(기울기)가 필요합니다. 아래는 경사하강법의 간단한 파이썬 코드 예시입니다.

# %%
import numpy as np

def gradient_descent(x, y, learning_rate, num_iterations):
    num_samples = x.shape[0]
    num_features = x.shape[1]
    theta = np.zeros(num_features)  # 초기 가중치를 0으로 설정

    x = np.concatenate((np.ones((num_samples, 1)), x), axis=1)
    
    for iteration in range(num_iterations):
        
        error = np.dot(x, theta) - y
        print(f"{iteration} iterations, error:", error)
        gradient = 1 / num_samples * np.dot(x.T, error)
        theta -= learning_rate * gradient

    return theta

# 데이터 준비
x = np.array([[1, 3], [1, 4], [1, 5], [1, 6]])  # 입력 변수 (여기서는 1차원과 2차원 값이 있음)
y = np.array([6, 8, 10, 12])  # 출력 변수

# 하이퍼파라미터 설정
learning_rate = 0.01
num_iterations = 1000

# 경사하강법 수행
theta = gradient_descent(x, y, learning_rate, num_iterations)

print("최적 가중치(theta):", theta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-0f9ced7f313a> in <cell line: 28>()
#      26
#      27 # 경사하강법 수행
# ---> 28 theta = gradient_descent(x, y, learning_rate, num_iterations)
#      29
#      30 print("최적 가중치(theta):", theta)
#
# <ipython-input-5-0f9ced7f313a> in gradient_descent(x, y, learning_rate, num_iterations)
#      10     for iteration in range(num_iterations):
#      11
# ---> 12         error = np.dot(x, theta) - y
#      13         print(f"{iteration} iterations, error:", error)
#      14         gradient = 1 / num_samples * np.dot(x.T, error)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in dot(*args, **kwargs)
#
# ValueError: shapes (4,3) and (2,) not aligned: 3 (dim 1) != 2 (dim 0)

# %%
import numpy as np

def gradient_descent(x, y, learning_rate, num_iterations):
    num_samples = x.shape[0]
    num_features = x.shape[1]
    theta = np.zeros(num_features + 1)  # Initializing weights with bias term


    # Adding a column of 1s for the bias term in the input data
    x = np.concatenate((np.ones((num_samples, 1)), x), axis=1)

    for iteration in range(num_iterations):
        error = np.dot(x, theta) - y
        print(f"iteration {iteration} error: {error}")
        
        gradient = 1 / num_samples * np.dot(x.T, error)
        theta -= learning_rate * gradient

    return theta

# Data preparation
x = np.array([[3], [4], [5], [6]])  # Input variable (only 1-dimensional for simplicity)
y = np.array([6, 8, 10, 12])  # Output variable

# Hyperparameter settings
learning_rate = 0.01
num_iterations = 1000

# Gradient descent execution
theta = gradient_descent(x, y, learning_rate, num_iterations)

print("Optimal weights (theta):", theta)
# Out:
# iteration 0 error: [ -6.  -8. -10. -12.]
# iteration 1 error: [-4.62 -6.19 -7.76 -9.33]
# iteration 2 error: [-3.54975 -4.78625 -6.02275 -7.25925]
# iteration 3 error: [-2.71972875 -3.69757    -4.67541125 -5.6532525 ]
# iteration 4 error: [-2.07601856 -2.85324472 -3.63047088 -4.40769703]
# iteration 5 error: [-1.5768032  -2.19843043 -2.82005766 -3.44168489]
# iteration 6 error: [-1.18965179 -1.6905927  -2.19153361 -2.69247451]
# iteration 7 error: [-0.88941235 -1.29674366 -1.70407496 -2.11140626]
# iteration 8 error: [-0.65657808 -0.99129932 -1.32602056 -1.66074181]
# iteration 9 error: [-0.47602034 -0.75441787 -1.0328154  -1.31121293]
# iteration 10 error: [-0.33600602 -0.57071083 -0.80541565 -1.04012046]
# iteration 11 error: [-0.22743542 -0.42824358 -0.62905173 -0.82985989]
# iteration 12 error: [-0.14325121 -0.31776011 -0.49226902 -0.66677793]
# iteration 13 error: [-0.07798001 -0.2320819  -0.38618379 -0.54028569]
# iteration 14 error: [-0.02737692 -0.16564157 -0.30390621 -0.44217085]
# iteration 15 error: [ 0.01185021 -0.1141213  -0.2400928  -0.36606431]
# iteration 16 error: [ 0.04225467 -0.07417238 -0.19059943 -0.30702647]
# iteration 17 error: [ 0.06581664 -0.04319771 -0.15221205 -0.26122639]
# iteration 18 error: [ 0.08407188 -0.01918306 -0.12243801 -0.22569295]
# iteration 19 error: [ 0.09821147 -0.00056631 -0.0993441  -0.19812188]
# iteration 20 error: [ 0.10915914  0.01386406 -0.08143101 -0.17672609]
# iteration 21 error: [ 0.11763131  0.02504768 -0.06753595 -0.16011959]
# iteration 22 error: [ 0.1241836   0.03371325 -0.0567571  -0.14722746]
# iteration 23 error: [ 0.12924691  0.04042593 -0.04839505 -0.13721604]
# iteration 24 error: [ 0.13315546  0.04562405 -0.04190737 -0.12943879]
# iteration 25 error: [ 0.13616843  0.04964753 -0.03687337 -0.12339427]
# iteration 26 error: [ 0.13848684  0.05276003 -0.03296677 -0.11869358]
# iteration 27 error: [ 0.14026658  0.05516601 -0.02993456 -0.11503513]
# iteration 28 error: [ 0.14162857  0.05702405 -0.02758047 -0.11218499]
# iteration 29 error: [ 0.14266658  0.05845714 -0.02575231 -0.10996175]
# iteration 30 error: [ 0.14345334  0.05956065 -0.02433203 -0.10822472]
# iteration 31 error: [ 0.14404524  0.06040857 -0.0232281  -0.10686477]
# iteration 32 error: [ 0.14448603  0.06105826 -0.02236952 -0.10579729]
# iteration 33 error: [ 0.14480964  0.06155422 -0.02170121 -0.10495663]
# iteration 34 error: [ 0.14504237  0.06193095 -0.02118047 -0.10429189]
# iteration 35 error: [ 0.14520464  0.06221523 -0.02077419 -0.1037636 ]
# iteration 36 error: [ 0.14531227  0.0624278  -0.02045667 -0.10334114]
# iteration 37 error: [ 0.14537753  0.06258476 -0.020208   -0.10300077]
# iteration 38 error: [ 0.14540994  0.06269861 -0.02001272 -0.10272406]
# iteration 39 error: [ 0.14541689  0.06277902 -0.01985886 -0.10249673]
# iteration 40 error: [ 0.1454041   0.0628335  -0.01973711 -0.10230771]
# iteration 41 error: [ 0.14537601  0.06286787 -0.01964027 -0.10214841]
# iteration 42 error: [ 0.14533606  0.06288665 -0.01956275 -0.10201216]
# iteration 43 error: [ 0.14528693  0.06289335 -0.01950022 -0.1018938 ]
# iteration 44 error: [ 0.14523069  0.06289069 -0.01944932 -0.10178932]
# iteration 45 error: [ 0.14516894  0.06288076 -0.01940743 -0.10169562]
# iteration 46 error: [ 0.14510293  0.0628652  -0.01937253 -0.10161027]
# iteration 47 error: [ 0.14503363  0.06284528 -0.01934306 -0.10153141]
# iteration 48 error: [ 0.14496178  0.06282199 -0.0193178  -0.1014576 ]
# iteration 49 error: [ 0.14488797  0.06279608 -0.01929581 -0.1013877 ]
# iteration 50 error: [ 0.14481265  0.06276815 -0.01927635 -0.10132084]
# iteration 51 error: [ 0.14473616  0.06273865 -0.01925885 -0.10125636]
# iteration 52 error: [ 0.14465878  0.06270795 -0.01924289 -0.10119372]
# iteration 53 error: [ 0.14458072  0.06267631 -0.0192281  -0.10113251]
# iteration 54 error: [ 0.14450214  0.06264395 -0.01921424 -0.10107243]
# iteration 55 error: [ 0.14442317  0.06261104 -0.0192011  -0.10101323]
# iteration 56 error: [ 0.1443439   0.0625777  -0.01918851 -0.10095471]
# iteration 57 error: [ 0.14426442  0.06254404 -0.01917635 -0.10089673]
# iteration 58 error: [ 0.14418478  0.06251012 -0.01916453 -0.10083918]
# iteration 59 error: [ 0.14410502  0.06247603 -0.01915297 -0.10078196]
# iteration 60 error: [ 0.14402519  0.06244178 -0.01914162 -0.10072502]
# iteration 61 error: [ 0.1439453   0.06240744 -0.01913042 -0.10066829]
# iteration 62 error: [ 0.14386539  0.06237302 -0.01911936 -0.10061173]
# iteration 63 error: [ 0.14378546  0.06233854 -0.01910839 -0.10055531]
# iteration 64 error: [ 0.14370553  0.06230402 -0.0190975  -0.10049901]
# iteration 65 error: [ 0.14362562  0.06226947 -0.01908667 -0.10044281]
# iteration 66 error: [ 0.14354572  0.06223492 -0.01907589 -0.10038669]
# iteration 67 error: [ 0.14346585  0.06220035 -0.01906515 -0.10033065]
# iteration 68 error: [ 0.143386    0.06216578 -0.01905444 -0.10027466]
# iteration 69 error: [ 0.14330619  0.06213121 -0.01904376 -0.10021873]
# iteration 70 error: [ 0.14322641  0.06209665 -0.0190331  -0.10016285]
# iteration 71 error: [ 0.14314667  0.0620621  -0.01902246 -0.10010702]
# iteration 72 error: [ 0.14306696  0.06202757 -0.01901183 -0.10005123]
# iteration 73 error: [ 0.1429873   0.06199304 -0.01900122 -0.09999548]
# iteration 74 error: [ 0.14290768  0.06195853 -0.01899062 -0.09993976]
# iteration 75 error: [ 0.1428281   0.06192404 -0.01898002 -0.09988408]
# iteration 76 error: [ 0.14274856  0.06188956 -0.01896944 -0.09982844]
# iteration 77 error: [ 0.14266906  0.0618551  -0.01895887 -0.09977283]
# iteration 78 error: [ 0.14258961  0.06182065 -0.0189483  -0.09971726]
# iteration 79 error: [ 0.1425102   0.06178623 -0.01893774 -0.09966172]
# iteration 80 error: [ 0.14243083  0.06175182 -0.01892719 -0.0996062 ]
# iteration 81 error: [ 0.14235151  0.06171743 -0.01891665 -0.09955073]
# iteration 82 error: [ 0.14227223  0.06168306 -0.01890611 -0.09949528]
# iteration 83 error: [ 0.142193    0.06164871 -0.01889558 -0.09943987]
# iteration 84 error: [ 0.14211381  0.06161438 -0.01888505 -0.09938448]
# iteration 85 error: [ 0.14203466  0.06158006 -0.01887453 -0.09932913]
# iteration 86 error: [ 0.14195555  0.06154577 -0.01886402 -0.09927381]
# iteration 87 error: [ 0.1418765   0.06151149 -0.01885351 -0.09921852]
# iteration 88 error: [ 0.14179748  0.06147723 -0.01884301 -0.09916326]
# iteration 89 error: [ 0.14171851  0.06144299 -0.01883252 -0.09910803]
# iteration 90 error: [ 0.14163958  0.06140877 -0.01882203 -0.09905284]
# iteration 91 error: [ 0.1415607   0.06137457 -0.01881155 -0.09899767]
# iteration 92 error: [ 0.14148186  0.06134039 -0.01880107 -0.09894253]
# iteration 93 error: [ 0.14140306  0.06130623 -0.0187906  -0.09888743]
# iteration 94 error: [ 0.14132431  0.06127209 -0.01878013 -0.09883236]
# iteration 95 error: [ 0.1412456   0.06123796 -0.01876967 -0.09877731]
# iteration 96 error: [ 0.14116694  0.06120386 -0.01875922 -0.0987223 ]
# iteration 97 error: [ 0.14108832  0.06116977 -0.01874877 -0.09866732]
# iteration 98 error: [ 0.14100974  0.0611357  -0.01873833 -0.09861237]
# iteration 99 error: [ 0.14093121  0.06110165 -0.0187279  -0.09855745]
# iteration 100 error: [ 0.14085272  0.06106763 -0.01871747 -0.09850256]
# iteration 101 error: [ 0.14077427  0.06103361 -0.01870704 -0.0984477 ]
# iteration 102 error: [ 0.14069587  0.06099962 -0.01869662 -0.09839287]
# iteration 103 error: [ 0.14061751  0.06096565 -0.01868621 -0.09833807]
# iteration 104 error: [ 0.1405392  0.0609317 -0.0186758 -0.0982833]
# iteration 105 error: [ 0.14046092  0.06089776 -0.0186654  -0.09822856]
# iteration 106 error: [ 0.1403827   0.06086385 -0.01865501 -0.09817386]
# iteration 107 error: [ 0.14030451  0.06082995 -0.01864462 -0.09811918]
# iteration 108 error: [ 0.14022637  0.06079607 -0.01863423 -0.09806454]
# iteration 109 error: [ 0.14014828  0.06076221 -0.01862385 -0.09800992]
# iteration 110 error: [ 0.14007022  0.06072837 -0.01861348 -0.09795533]
# iteration 111 error: [ 0.13999221  0.06069455 -0.01860312 -0.09790078]
# iteration 112 error: [ 0.13991425  0.06066075 -0.01859276 -0.09784626]
# iteration 113 error: [ 0.13983632  0.06062696 -0.0185824  -0.09779176]
# iteration 114 error: [ 0.13975844  0.0605932  -0.01857205 -0.0977373 ]
# iteration 115 error: [ 0.13968061  0.06055945 -0.01856171 -0.09768287]
# iteration 116 error: [ 0.13960281  0.06052572 -0.01855137 -0.09762846]
# iteration 117 error: [ 0.13952506  0.06049201 -0.01854104 -0.09757409]
# iteration 118 error: [ 0.13944736  0.06045832 -0.01853071 -0.09751975]
# iteration 119 error: [ 0.1393697   0.06042465 -0.01852039 -0.09746544]
# iteration 120 error: [ 0.13929208  0.060391   -0.01851008 -0.09741115]
# iteration 121 error: [ 0.1392145   0.06035737 -0.01849977 -0.0973569 ]
# iteration 122 error: [ 0.13913697  0.06032375 -0.01848946 -0.09730268]
# iteration 123 error: [ 0.13905948  0.06029015 -0.01847917 -0.09724849]
# iteration 124 error: [ 0.13898203  0.06025658 -0.01846888 -0.09719433]
# iteration 125 error: [ 0.13890462  0.06022302 -0.01845859 -0.0971402 ]
# iteration 126 error: [ 0.13882726  0.06018948 -0.01844831 -0.0970861 ]
# iteration 127 error: [ 0.13874995  0.06015596 -0.01843804 -0.09703203]
# iteration 128 error: [ 0.13867267  0.06012245 -0.01842777 -0.09697799]
# iteration 129 error: [ 0.13859544  0.06008897 -0.0184175  -0.09692398]
# iteration 130 error: [ 0.13851825  0.0600555  -0.01840725 -0.09687   ]
# iteration 131 error: [ 0.13844111  0.06002206 -0.01839699 -0.09681604]
# iteration 132 error: [ 0.138364    0.05998863 -0.01838675 -0.09676212]
# iteration 133 error: [ 0.13828694  0.05995522 -0.01837651 -0.09670823]
# iteration 134 error: [ 0.13820993  0.05992183 -0.01836627 -0.09665437]
# iteration 135 error: [ 0.13813295  0.05988845 -0.01835604 -0.09660054]
# iteration 136 error: [ 0.13805602  0.0598551  -0.01834582 -0.09654674]
# iteration 137 error: [ 0.13797913  0.05982177 -0.0183356  -0.09649297]
# iteration 138 error: [ 0.13790229  0.05978845 -0.01832539 -0.09643923]
# iteration 139 error: [ 0.13782549  0.05975515 -0.01831519 -0.09638552]
# iteration 140 error: [ 0.13774873  0.05972187 -0.01830499 -0.09633184]
# iteration 141 error: [ 0.13767201  0.05968861 -0.01829479 -0.09627819]
# iteration 142 error: [ 0.13759534  0.05965537 -0.0182846  -0.09622457]
# iteration 143 error: [ 0.1375187   0.05962214 -0.01827442 -0.09617098]
# iteration 144 error: [ 0.13744212  0.05958894 -0.01826424 -0.09611742]
# iteration 145 error: [ 0.13736557  0.05955575 -0.01825407 -0.09606389]
# iteration 146 error: [ 0.13728907  0.05952258 -0.0182439  -0.09601039]
# iteration 147 error: [ 0.1372126   0.05948943 -0.01823374 -0.09595692]
# iteration 148 error: [ 0.13713619  0.0594563  -0.01822359 -0.09590347]
# iteration 149 error: [ 0.13705981  0.05942319 -0.01821344 -0.09585006]
# iteration 150 error: [ 0.13698348  0.05939009 -0.01820329 -0.09579668]
# iteration 151 error: [ 0.13690719  0.05935701 -0.01819316 -0.09574333]
# iteration 152 error: [ 0.13683094  0.05932396 -0.01818302 -0.09569001]
# iteration 153 error: [ 0.13675473  0.05929092 -0.0181729  -0.09563671]
# iteration 154 error: [ 0.13667857  0.0592579  -0.01816278 -0.09558345]
# iteration 155 error: [ 0.13660245  0.05922489 -0.01815266 -0.09553022]
# iteration 156 error: [ 0.13652637  0.05919191 -0.01814255 -0.09547701]
# iteration 157 error: [ 0.13645033  0.05915894 -0.01813245 -0.09542384]
# iteration 158 error: [ 0.13637434  0.059126   -0.01812235 -0.09537069]
# iteration 159 error: [ 0.13629839  0.05909307 -0.01811226 -0.09531758]
# iteration 160 error: [ 0.13622248  0.05906016 -0.01810217 -0.09526449]
# iteration 161 error: [ 0.13614661  0.05902726 -0.01809209 -0.09521144]
# iteration 162 error: [ 0.13607079  0.05899439 -0.01808201 -0.09515841]
# iteration 163 error: [ 0.135995    0.05896153 -0.01807194 -0.09510541]
# iteration 164 error: [ 0.13591926  0.05892869 -0.01806187 -0.09505244]
# iteration 165 error: [ 0.13584357  0.05889588 -0.01805182 -0.09499951]
# iteration 166 error: [ 0.13576791  0.05886307 -0.01804176 -0.0949466 ]
# iteration 167 error: [ 0.1356923   0.05883029 -0.01803171 -0.09489372]
# iteration 168 error: [ 0.13561672  0.05879753 -0.01802167 -0.09484087]
# iteration 169 error: [ 0.1355412   0.05876478 -0.01801163 -0.09478805]
# iteration 170 error: [ 0.13546571  0.05873205 -0.0180016  -0.09473526]
# iteration 171 error: [ 0.13539026  0.05869934 -0.01799158 -0.0946825 ]
# iteration 172 error: [ 0.13531486  0.05866665 -0.01798156 -0.09462977]
# iteration 173 error: [ 0.1352395   0.05863398 -0.01797154 -0.09457706]
# iteration 174 error: [ 0.13516418  0.05860132 -0.01796153 -0.09452439]
# iteration 175 error: [ 0.1350889   0.05856868 -0.01795153 -0.09447175]
# iteration 176 error: [ 0.13501366  0.05853607 -0.01794153 -0.09441913]
# iteration 177 error: [ 0.13493847  0.05850347 -0.01793154 -0.09436655]
# iteration 178 error: [ 0.13486332  0.05847088 -0.01792155 -0.09431399]
# iteration 179 error: [ 0.13478821  0.05843832 -0.01791157 -0.09426146]
# iteration 180 error: [ 0.13471314  0.05840577 -0.0179016  -0.09420897]
# iteration 181 error: [ 0.13463811  0.05837324 -0.01789163 -0.0941565 ]
# iteration 182 error: [ 0.13456313  0.05834073 -0.01788166 -0.09410406]
# iteration 183 error: [ 0.13448819  0.05830824 -0.0178717  -0.09405165]
# iteration 184 error: [ 0.13441329  0.05827577 -0.01786175 -0.09399927]
# iteration 185 error: [ 0.13433843  0.05824331 -0.0178518  -0.09394692]
# iteration 186 error: [ 0.13426361  0.05821087 -0.01784186 -0.0938946 ]
# iteration 187 error: [ 0.13418883  0.05817845 -0.01783192 -0.0938423 ]
# iteration 188 error: [ 0.1341141   0.05814605 -0.01782199 -0.09379004]
# iteration 189 error: [ 0.13403941  0.05811367 -0.01781207 -0.0937378 ]
# iteration 190 error: [ 0.13396476  0.0580813  -0.01780215 -0.0936856 ]
# iteration 191 error: [ 0.13389015  0.05804896 -0.01779223 -0.09363342]
# iteration 192 error: [ 0.13381558  0.05801663 -0.01778232 -0.09358127]
# iteration 193 error: [ 0.13374105  0.05798432 -0.01777242 -0.09352915]
# iteration 194 error: [ 0.13366657  0.05795202 -0.01776252 -0.09347706]
# iteration 195 error: [ 0.13359212  0.05791975 -0.01775263 -0.093425  ]
# iteration 196 error: [ 0.13351772  0.05788749 -0.01774274 -0.09337297]
# iteration 197 error: [ 0.13344336  0.05785525 -0.01773286 -0.09332097]
# iteration 198 error: [ 0.13336904  0.05782303 -0.01772298 -0.093269  ]
# iteration 199 error: [ 0.13329476  0.05779082 -0.01771311 -0.09321705]
# iteration 200 error: [ 0.13322053  0.05775864 -0.01770325 -0.09316514]
# iteration 201 error: [ 0.13314633  0.05772647 -0.01769339 -0.09311325]
# iteration 202 error: [ 0.13307218  0.05769432 -0.01768353 -0.09306139]
# iteration 203 error: [ 0.13299807  0.05766219 -0.01767369 -0.09300956]
# iteration 204 error: [ 0.13292399  0.05763008 -0.01766384 -0.09295776]
# iteration 205 error: [ 0.13284996  0.05759798 -0.01765401 -0.09290599]
# iteration 206 error: [ 0.13277598  0.0575659  -0.01764417 -0.09285425]
# iteration 207 error: [ 0.13270203  0.05753384 -0.01763435 -0.09280253]
# iteration 208 error: [ 0.13262812  0.0575018  -0.01762453 -0.09275085]
# iteration 209 error: [ 0.13255426  0.05746977 -0.01761471 -0.09269919]
# iteration 210 error: [ 0.13248043  0.05743777 -0.0176049  -0.09264757]
# iteration 211 error: [ 0.13240665  0.05740578 -0.01759509 -0.09259597]
# iteration 212 error: [ 0.13233291  0.05737381 -0.0175853  -0.0925444 ]
# iteration 213 error: [ 0.13225921  0.05734185 -0.0175755  -0.09249286]
# iteration 214 error: [ 0.13218555  0.05730992 -0.01756571 -0.09244134]
# iteration 215 error: [ 0.13211193  0.057278   -0.01755593 -0.09238986]
# iteration 216 error: [ 0.13203835  0.0572461  -0.01754615 -0.09233841]
# iteration 217 error: [ 0.13196482  0.05721422 -0.01753638 -0.09228698]
# iteration 218 error: [ 0.13189132  0.05718235 -0.01752661 -0.09223558]
# iteration 219 error: [ 0.13181786  0.05715051 -0.01751685 -0.09218421]
# iteration 220 error: [ 0.13174445  0.05711868 -0.0175071  -0.09213287]
# iteration 221 error: [ 0.13167108  0.05708687 -0.01749735 -0.09208156]
# iteration 222 error: [ 0.13159775  0.05705507 -0.0174876  -0.09203028]
# iteration 223 error: [ 0.13152445  0.0570233  -0.01747786 -0.09197902]
# iteration 224 error: [ 0.1314512   0.05699154 -0.01746813 -0.09192779]
# iteration 225 error: [ 0.13137799  0.0569598  -0.0174584  -0.0918766 ]
# iteration 226 error: [ 0.13130483  0.05692807 -0.01744868 -0.09182543]
# iteration 227 error: [ 0.1312317   0.05689637 -0.01743896 -0.09177429]
# iteration 228 error: [ 0.13115861  0.05686468 -0.01742925 -0.09172318]
# iteration 229 error: [ 0.13108556  0.05683301 -0.01741954 -0.09167209]
# iteration 230 error: [ 0.13101256  0.05680136 -0.01740984 -0.09162104]
# iteration 231 error: [ 0.13093959  0.05676972 -0.01740014 -0.09157001]
# iteration 232 error: [ 0.13086667  0.05673811 -0.01739045 -0.09151901]
# iteration 233 error: [ 0.13079378  0.05670651 -0.01738077 -0.09146804]
# iteration 234 error: [ 0.13072094  0.05667493 -0.01737109 -0.0914171 ]
# iteration 235 error: [ 0.13064814  0.05664336 -0.01736141 -0.09136619]
# iteration 236 error: [ 0.13057537  0.05661182 -0.01735174 -0.0913153 ]
# iteration 237 error: [ 0.13050265  0.05658029 -0.01734208 -0.09126444]
# iteration 238 error: [ 0.13042997  0.05654878 -0.01733242 -0.09121362]
# iteration 239 error: [ 0.13035733  0.05651728 -0.01732277 -0.09116282]
# iteration 240 error: [ 0.13028473  0.0564858  -0.01731312 -0.09111204]
# iteration 241 error: [ 0.13021217  0.05645435 -0.01730348 -0.0910613 ]
# iteration 242 error: [ 0.13013965  0.0564229  -0.01729384 -0.09101059]
# iteration 243 error: [ 0.13006717  0.05639148 -0.01728421 -0.0909599 ]
# iteration 244 error: [ 0.12999473  0.05636007 -0.01727458 -0.09090924]
# iteration 245 error: [ 0.12992233  0.05632869 -0.01726496 -0.09085861]
# iteration 246 error: [ 0.12984998  0.05629731 -0.01725535 -0.09080801]
# iteration 247 error: [ 0.12977766  0.05626596 -0.01724574 -0.09075743]
# iteration 248 error: [ 0.12970538  0.05623462 -0.01723613 -0.09070689]
# iteration 249 error: [ 0.12963314  0.0562033  -0.01722653 -0.09065637]
# iteration 250 error: [ 0.12956095  0.056172   -0.01721694 -0.09060588]
# iteration 251 error: [ 0.12948879  0.05614072 -0.01720735 -0.09055542]
# iteration 252 error: [ 0.12941667  0.05610945 -0.01719777 -0.09050499]
# iteration 253 error: [ 0.12934459  0.0560782  -0.01718819 -0.09045458]
# iteration 254 error: [ 0.12927256  0.05604697 -0.01717862 -0.0904042 ]
# iteration 255 error: [ 0.12920056  0.05601576 -0.01716905 -0.09035385]
# iteration 256 error: [ 0.12912861  0.05598456 -0.01715949 -0.09030353]
# iteration 257 error: [ 0.12905669  0.05595338 -0.01714993 -0.09025324]
# iteration 258 error: [ 0.12898481  0.05592222 -0.01714038 -0.09020297]
# iteration 259 error: [ 0.12891298  0.05589107 -0.01713083 -0.09015274]
# iteration 260 error: [ 0.12884118  0.05585995 -0.01712129 -0.09010253]
# iteration 261 error: [ 0.12876943  0.05582883 -0.01711176 -0.09005235]
# iteration 262 error: [ 0.12869771  0.05579774 -0.01710223 -0.09000219]
# iteration 263 error: [ 0.12862603  0.05576667 -0.0170927  -0.08995207]
# iteration 264 error: [ 0.1285544   0.05573561 -0.01708318 -0.08990197]
# iteration 265 error: [ 0.1284828   0.05570457 -0.01707367 -0.0898519 ]
# iteration 266 error: [ 0.12841124  0.05567354 -0.01706416 -0.08980186]
# iteration 267 error: [ 0.12833973  0.05564254 -0.01705465 -0.08975185]
# iteration 268 error: [ 0.12826825  0.05561155 -0.01704516 -0.08970186]
# iteration 269 error: [ 0.12819681  0.05558058 -0.01703566 -0.0896519 ]
# iteration 270 error: [ 0.12812542  0.05554962 -0.01702618 -0.08960197]
# iteration 271 error: [ 0.12805406  0.05551868 -0.01701669 -0.08955207]
# iteration 272 error: [ 0.12798274  0.05548776 -0.01700722 -0.08950219]
# iteration 273 error: [ 0.12791146  0.05545686 -0.01699774 -0.08945235]
# iteration 274 error: [ 0.12784023  0.05542597 -0.01698828 -0.08940253]
# iteration 275 error: [ 0.12776903  0.05539511 -0.01697882 -0.08935274]
# iteration 276 error: [ 0.12769787  0.05536425 -0.01696936 -0.08930297]
# iteration 277 error: [ 0.12762675  0.05533342 -0.01695991 -0.08925324]
# iteration 278 error: [ 0.12755567  0.0553026  -0.01695046 -0.08920353]
# iteration 279 error: [ 0.12748463  0.0552718  -0.01694102 -0.08915385]
# iteration 280 error: [ 0.12741363  0.05524102 -0.01693159 -0.0891042 ]
# iteration 281 error: [ 0.12734267  0.05521025 -0.01692216 -0.08905457]
# iteration 282 error: [ 0.12727175  0.05517951 -0.01691273 -0.08900497]
# iteration 283 error: [ 0.12720086  0.05514877 -0.01690331 -0.0889554 ]
# iteration 284 error: [ 0.12713002  0.05511806 -0.0168939  -0.08890586]
# iteration 285 error: [ 0.12705922  0.05508736 -0.01688449 -0.08885635]
# iteration 286 error: [ 0.12698845  0.05505668 -0.01687509 -0.08880686]
# iteration 287 error: [ 0.12691773  0.05502602 -0.01686569 -0.0887574 ]
# iteration 288 error: [ 0.12684705  0.05499537 -0.0168563  -0.08870797]
# iteration 289 error: [ 0.1267764   0.05496475 -0.01684691 -0.08865856]
# iteration 290 error: [ 0.12670579  0.05493413 -0.01683753 -0.08860919]
# iteration 291 error: [ 0.12663523  0.05490354 -0.01682815 -0.08855984]
# iteration 292 error: [ 0.1265647   0.05487296 -0.01681878 -0.08851052]
# iteration 293 error: [ 0.12649421  0.0548424  -0.01680941 -0.08846122]
# iteration 294 error: [ 0.12642376  0.05481186 -0.01680005 -0.08841195]
# iteration 295 error: [ 0.12635335  0.05478133 -0.01679069 -0.08836271]
# iteration 296 error: [ 0.12628298  0.05475082 -0.01678134 -0.0883135 ]
# iteration 297 error: [ 0.12621265  0.05472033 -0.01677199 -0.08826432]
# iteration 298 error: [ 0.12614236  0.05468985 -0.01676265 -0.08821516]
# iteration 299 error: [ 0.12607211  0.05465939 -0.01675332 -0.08816603]
# iteration 300 error: [ 0.12600189  0.05462895 -0.01674399 -0.08811693]
# iteration 301 error: [ 0.12593172  0.05459853 -0.01673466 -0.08806785]
# iteration 302 error: [ 0.12586158  0.05456812 -0.01672534 -0.0880188 ]
# iteration 303 error: [ 0.12579149  0.05453773 -0.01671603 -0.08796978]
# iteration 304 error: [ 0.12572143  0.05450736 -0.01670672 -0.08792079]
# iteration 305 error: [ 0.12565141  0.054477   -0.01669741 -0.08787182]
# iteration 306 error: [ 0.12558143  0.05444666 -0.01668811 -0.08782288]
# iteration 307 error: [ 0.12551149  0.05441634 -0.01667882 -0.08777397]
# iteration 308 error: [ 0.12544159  0.05438603 -0.01666953 -0.08772509]
# iteration 309 error: [ 0.12537172  0.05435574 -0.01666025 -0.08767623]
# iteration 310 error: [ 0.1253019   0.05432547 -0.01665097 -0.0876274 ]
# iteration 311 error: [ 0.12523212  0.05429521 -0.01664169 -0.0875786 ]
# iteration 312 error: [ 0.12516237  0.05426497 -0.01663243 -0.08752982]
# iteration 313 error: [ 0.12509266  0.05423475 -0.01662316 -0.08748108]
# iteration 314 error: [ 0.12502299  0.05420454 -0.0166139  -0.08743235]
# iteration 315 error: [ 0.12495336  0.05417436 -0.01660465 -0.08738366]
# iteration 316 error: [ 0.12488377  0.05414419 -0.0165954  -0.08733499]
# iteration 317 error: [ 0.12481422  0.05411403 -0.01658616 -0.08728635]
# iteration 318 error: [ 0.12474471  0.05408389 -0.01657692 -0.08723774]
# iteration 319 error: [ 0.12467523  0.05405377 -0.01656769 -0.08718915]
# iteration 320 error: [ 0.1246058   0.05402367 -0.01655846 -0.0871406 ]
# iteration 321 error: [ 0.1245364   0.05399358 -0.01654924 -0.08709206]
# iteration 322 error: [ 0.12446704  0.05396351 -0.01654003 -0.08704356]
# iteration 323 error: [ 0.12439772  0.05393345 -0.01653081 -0.08699508]
# iteration 324 error: [ 0.12432844  0.05390342 -0.01652161 -0.08694663]
# iteration 325 error: [ 0.1242592   0.0538734  -0.01651241 -0.08689821]
# iteration 326 error: [ 0.12418999  0.05384339 -0.01650321 -0.08684981]
# iteration 327 error: [ 0.12412083  0.05381341 -0.01649402 -0.08680144]
# iteration 328 error: [ 0.1240517   0.05378343 -0.01648483 -0.0867531 ]
# iteration 329 error: [ 0.12398261  0.05375348 -0.01647565 -0.08670478]
# iteration 330 error: [ 0.12391356  0.05372354 -0.01646648 -0.0866565 ]
# iteration 331 error: [ 0.12384455  0.05369362 -0.01645731 -0.08660823]
# iteration 332 error: [ 0.12377558  0.05366372 -0.01644814 -0.08656   ]
# iteration 333 error: [ 0.12370664  0.05363383 -0.01643898 -0.08651179]
# iteration 334 error: [ 0.12363775  0.05360396 -0.01642982 -0.08646361]
# iteration 335 error: [ 0.12356889  0.05357411 -0.01642067 -0.08641545]
# iteration 336 error: [ 0.12350007  0.05354427 -0.01641153 -0.08636733]
# iteration 337 error: [ 0.12343129  0.05351445 -0.01640239 -0.08631923]
# iteration 338 error: [ 0.12336254  0.05348465 -0.01639325 -0.08627115]
# iteration 339 error: [ 0.12329384  0.05345486 -0.01638412 -0.0862231 ]
# iteration 340 error: [ 0.12322517  0.05342509 -0.016375   -0.08617508]
# iteration 341 error: [ 0.12315654  0.05339533 -0.01636588 -0.08612709]
# iteration 342 error: [ 0.12308795  0.0533656  -0.01635676 -0.08607912]
# iteration 343 error: [ 0.1230194   0.05333587 -0.01634765 -0.08603118]
# iteration 344 error: [ 0.12295089  0.05330617 -0.01633855 -0.08598327]
# iteration 345 error: [ 0.12288241  0.05327648 -0.01632945 -0.08593538]
# iteration 346 error: [ 0.12281398  0.05324681 -0.01632036 -0.08588752]
# iteration 347 error: [ 0.12274558  0.05321716 -0.01631127 -0.08583969]
# iteration 348 error: [ 0.12267722  0.05318752 -0.01630218 -0.08579188]
# iteration 349 error: [ 0.12260889  0.0531579  -0.0162931  -0.0857441 ]
# iteration 350 error: [ 0.12254061  0.05312829 -0.01628403 -0.08569635]
# iteration 351 error: [ 0.12247236  0.0530987  -0.01627496 -0.08564862]
# iteration 352 error: [ 0.12240415  0.05306913 -0.01626589 -0.08560092]
# iteration 353 error: [ 0.12233598  0.05303957 -0.01625684 -0.08555324]
# iteration 354 error: [ 0.12226785  0.05301003 -0.01624778 -0.0855056 ]
# iteration 355 error: [ 0.12219975  0.05298051 -0.01623873 -0.08545798]
# iteration 356 error: [ 0.12213169  0.052951   -0.01622969 -0.08541038]
# iteration 357 error: [ 0.12206368  0.05292151 -0.01622065 -0.08536281]
# iteration 358 error: [ 0.12199569  0.05289204 -0.01621162 -0.08531527]
# iteration 359 error: [ 0.12192775  0.05286258 -0.01620259 -0.08526776]
# iteration 360 error: [ 0.12185984  0.05283314 -0.01619356 -0.08522027]
# iteration 361 error: [ 0.12179198  0.05280372 -0.01618454 -0.08517281]
# iteration 362 error: [ 0.12172415  0.05277431 -0.01617553 -0.08512537]
# iteration 363 error: [ 0.12165635  0.05274492 -0.01616652 -0.08507796]
# iteration 364 error: [ 0.1215886   0.05271554 -0.01615752 -0.08503058]
# iteration 365 error: [ 0.12152088  0.05268618 -0.01614852 -0.08498322]
# iteration 366 error: [ 0.1214532   0.05265684 -0.01613953 -0.08493589]
# iteration 367 error: [ 0.12138556  0.05262751 -0.01613054 -0.08488859]
# iteration 368 error: [ 0.12131796  0.0525982  -0.01612155 -0.08484131]
# iteration 369 error: [ 0.12125039  0.05256891 -0.01611258 -0.08479406]
# iteration 370 error: [ 0.12118286  0.05253963 -0.0161036  -0.08474683]
# iteration 371 error: [ 0.12111537  0.05251037 -0.01609463 -0.08469964]
# iteration 372 error: [ 0.12104792  0.05248113 -0.01608567 -0.08465246]
# iteration 373 error: [ 0.1209805   0.0524519  -0.01607671 -0.08460532]
# iteration 374 error: [ 0.12091313  0.05242268 -0.01606776 -0.0845582 ]
# iteration 375 error: [ 0.12084579  0.05239349 -0.01605881 -0.08451111]
# iteration 376 error: [ 0.12077848  0.05236431 -0.01604986 -0.08446404]
# iteration 377 error: [ 0.12071122  0.05233515 -0.01604093 -0.084417  ]
# iteration 378 error: [ 0.12064399  0.052306   -0.01603199 -0.08436998]
# iteration 379 error: [ 0.1205768   0.05227687 -0.01602306 -0.08432299]
# iteration 380 error: [ 0.12050964  0.05224775 -0.01601414 -0.08427603]
# iteration 381 error: [ 0.12044253  0.05221865 -0.01600522 -0.0842291 ]
# iteration 382 error: [ 0.12037545  0.05218957 -0.01599631 -0.08418219]
# iteration 383 error: [ 0.12030841  0.05216051 -0.0159874  -0.0841353 ]
# iteration 384 error: [ 0.1202414   0.05213146 -0.01597849 -0.08408844]
# iteration 385 error: [ 0.12017444  0.05210242 -0.0159696  -0.08404161]
# iteration 386 error: [ 0.12010751  0.0520734  -0.0159607  -0.08399481]
# iteration 387 error: [ 0.12004062  0.0520444  -0.01595181 -0.08394803]
# iteration 388 error: [ 0.11997376  0.05201542 -0.01594293 -0.08390127]
# iteration 389 error: [ 0.11990694  0.05198645 -0.01593405 -0.08385455]
# iteration 390 error: [ 0.11984016  0.05195749 -0.01592517 -0.08380784]
# iteration 391 error: [ 0.11977342  0.05192856 -0.01591631 -0.08376117]
# iteration 392 error: [ 0.11970672  0.05189964 -0.01590744 -0.08371452]
# iteration 393 error: [ 0.11964005  0.05187073 -0.01589858 -0.0836679 ]
# iteration 394 error: [ 0.11957342  0.05184184 -0.01588973 -0.0836213 ]
# iteration 395 error: [ 0.11950682  0.05181297 -0.01588088 -0.08357473]
# iteration 396 error: [ 0.11944026  0.05178411 -0.01587203 -0.08352818]
# iteration 397 error: [ 0.11937374  0.05175527 -0.01586319 -0.08348166]
# iteration 398 error: [ 0.11930726  0.05172645 -0.01585436 -0.08343517]
# iteration 399 error: [ 0.11924081  0.05169764 -0.01584553 -0.0833887 ]
# iteration 400 error: [ 0.1191744   0.05166885 -0.0158367  -0.08334226]
# iteration 401 error: [ 0.11910803  0.05164007 -0.01582788 -0.08329584]
# iteration 402 error: [ 0.1190417   0.05161131 -0.01581907 -0.08324945]
# iteration 403 error: [ 0.1189754   0.05158257 -0.01581026 -0.08320309]
# iteration 404 error: [ 0.11890914  0.05155384 -0.01580145 -0.08315675]
# iteration 405 error: [ 0.11884291  0.05152513 -0.01579265 -0.08311044]
# iteration 406 error: [ 0.11877672  0.05149643 -0.01578386 -0.08306415]
# iteration 407 error: [ 0.11871057  0.05146775 -0.01577507 -0.08301789]
# iteration 408 error: [ 0.11864446  0.05143909 -0.01576628 -0.08297165]
# iteration 409 error: [ 0.11857838  0.05141044 -0.0157575  -0.08292544]
# iteration 410 error: [ 0.11851234  0.05138181 -0.01574872 -0.08287926]
# iteration 411 error: [ 0.11844634  0.05135319 -0.01573995 -0.0828331 ]
# iteration 412 error: [ 0.11838037  0.05132459 -0.01573119 -0.08278697]
# iteration 413 error: [ 0.11831444  0.05129601 -0.01572243 -0.08274086]
# iteration 414 error: [ 0.11824855  0.05126744 -0.01571367 -0.08269478]
# iteration 415 error: [ 0.11818269  0.05123889 -0.01570492 -0.08264872]
# iteration 416 error: [ 0.11811687  0.05121035 -0.01569617 -0.08260269]
# iteration 417 error: [ 0.11805109  0.05118183 -0.01568743 -0.08255669]
# iteration 418 error: [ 0.11798534  0.05115332 -0.01567869 -0.08251071]
# iteration 419 error: [ 0.11791963  0.05112484 -0.01566996 -0.08246476]
# iteration 420 error: [ 0.11785396  0.05109636 -0.01566123 -0.08241883]
# iteration 421 error: [ 0.11778832  0.0510679  -0.01565251 -0.08237293]
# iteration 422 error: [ 0.11772272  0.05103946 -0.01564379 -0.08232705]
# iteration 423 error: [ 0.11765716  0.05101104 -0.01563508 -0.0822812 ]
# iteration 424 error: [ 0.11759163  0.05098263 -0.01562637 -0.08223538]
# iteration 425 error: [ 0.11752614  0.05095423 -0.01561767 -0.08218958]
# iteration 426 error: [ 0.11746068  0.05092586 -0.01560897 -0.0821438 ]
# iteration 427 error: [ 0.11739527  0.05089749 -0.01560028 -0.08209805]
# iteration 428 error: [ 0.11732989  0.05086915 -0.01559159 -0.08205233]
# iteration 429 error: [ 0.11726454  0.05084082 -0.01558291 -0.08200663]
# iteration 430 error: [ 0.11719923  0.0508125  -0.01557423 -0.08196096]
# iteration 431 error: [ 0.11713396  0.0507842  -0.01556556 -0.08191531]
# iteration 432 error: [ 0.11706872  0.05075592 -0.01555689 -0.08186969]
# iteration 433 error: [ 0.11700352  0.05072765 -0.01554822 -0.0818241 ]
# iteration 434 error: [ 0.11693836  0.0506994  -0.01553956 -0.08177853]
# iteration 435 error: [ 0.11687323  0.05067116 -0.01553091 -0.08173298]
# iteration 436 error: [ 0.11680814  0.05064294 -0.01552226 -0.08168746]
# iteration 437 error: [ 0.11674309  0.05061474 -0.01551361 -0.08164197]
# iteration 438 error: [ 0.11667807  0.05058655 -0.01550497 -0.0815965 ]
# iteration 439 error: [ 0.11661309  0.05055837 -0.01549634 -0.08155105]
# iteration 440 error: [ 0.11654814  0.05053022 -0.01548771 -0.08150563]
# iteration 441 error: [ 0.11648323  0.05050207 -0.01547908 -0.08146024]
# iteration 442 error: [ 0.11641836  0.05047395 -0.01547046 -0.08141487]
# iteration 443 error: [ 0.11635352  0.05044584 -0.01546185 -0.08136953]
# iteration 444 error: [ 0.11628872  0.05041774 -0.01545323 -0.08132421]
# iteration 445 error: [ 0.11622396  0.05038966 -0.01544463 -0.08127892]
# iteration 446 error: [ 0.11615923  0.0503616  -0.01543603 -0.08123365]
# iteration 447 error: [ 0.11609453  0.05033355 -0.01542743 -0.08118841]
# iteration 448 error: [ 0.11602988  0.05030552 -0.01541884 -0.0811432 ]
# iteration 449 error: [ 0.11596526  0.0502775  -0.01541025 -0.081098  ]
# iteration 450 error: [ 0.11590067  0.0502495  -0.01540167 -0.08105284]
# iteration 451 error: [ 0.11583612  0.05022152 -0.01539309 -0.0810077 ]
# iteration 452 error: [ 0.11577161  0.05019355 -0.01538452 -0.08096258]
# iteration 453 error: [ 0.11570713  0.05016559 -0.01537595 -0.08091749]
# iteration 454 error: [ 0.11564269  0.05013765 -0.01536739 -0.08087242]
# iteration 455 error: [ 0.11557828  0.05010973 -0.01535883 -0.08082738]
# iteration 456 error: [ 0.11551392  0.05008182 -0.01535027 -0.08078237]
# iteration 457 error: [ 0.11544958  0.05005393 -0.01534172 -0.08073738]
# iteration 458 error: [ 0.11538528  0.05002605 -0.01533318 -0.08069241]
# iteration 459 error: [ 0.11532102  0.04999819 -0.01532464 -0.08064747]
# iteration 460 error: [ 0.1152568   0.04997034 -0.01531611 -0.08060256]
# iteration 461 error: [ 0.11519261  0.04994251 -0.01530758 -0.08055767]
# iteration 462 error: [ 0.11512845  0.0499147  -0.01529905 -0.0805128 ]
# iteration 463 error: [ 0.11506433  0.0498869  -0.01529053 -0.08046796]
# iteration 464 error: [ 0.11500025  0.04985912 -0.01528201 -0.08042315]
# iteration 465 error: [ 0.1149362   0.04983135 -0.0152735  -0.08037835]
# iteration 466 error: [ 0.11487219  0.0498036  -0.015265   -0.08033359]
# iteration 467 error: [ 0.11480821  0.04977586 -0.01525649 -0.08028885]
# iteration 468 error: [ 0.11474427  0.04974814 -0.015248   -0.08024413]
# iteration 469 error: [ 0.11468037  0.04972043 -0.01523951 -0.08019944]
# iteration 470 error: [ 0.1146165   0.04969274 -0.01523102 -0.08015478]
# iteration 471 error: [ 0.11455266  0.04966506 -0.01522254 -0.08011014]
# iteration 472 error: [ 0.11448887  0.0496374  -0.01521406 -0.08006552]
# iteration 473 error: [ 0.1144251   0.04960976 -0.01520558 -0.08002093]
# iteration 474 error: [ 0.11436138  0.04958213 -0.01519712 -0.07997636]
# iteration 475 error: [ 0.11429768  0.04955452 -0.01518865 -0.07993182]
# iteration 476 error: [ 0.11423403  0.04952692 -0.01518019 -0.0798873 ]
# iteration 477 error: [ 0.11417041  0.04949933 -0.01517174 -0.07984281]
# iteration 478 error: [ 0.11410682  0.04947177 -0.01516329 -0.07979834]
# iteration 479 error: [ 0.11404327  0.04944421 -0.01515484 -0.0797539 ]
# iteration 480 error: [ 0.11397976  0.04941668 -0.0151464  -0.07970948]
# iteration 481 error: [ 0.11391628  0.04938915 -0.01513797 -0.07966509]
# iteration 482 error: [ 0.11385283  0.04936165 -0.01512954 -0.07962072]
# iteration 483 error: [ 0.11378943  0.04933416 -0.01512111 -0.07957638]
# iteration 484 error: [ 0.11372605  0.04930668 -0.01511269 -0.07953206]
# iteration 485 error: [ 0.11366271  0.04927922 -0.01510427 -0.07948777]
# iteration 486 error: [ 0.11359941  0.04925178 -0.01509586 -0.0794435 ]
# iteration 487 error: [ 0.11353614  0.04922435 -0.01508745 -0.07939925]
# iteration 488 error: [ 0.11347291  0.04919693 -0.01507905 -0.07935503]
# iteration 489 error: [ 0.11340971  0.04916953 -0.01507065 -0.07931084]
# iteration 490 error: [ 0.11334655  0.04914215 -0.01506226 -0.07926667]
# iteration 491 error: [ 0.11328343  0.04911478 -0.01505387 -0.07922252]
# iteration 492 error: [ 0.11322034  0.04908742 -0.01504549 -0.0791784 ]
# iteration 493 error: [ 0.11315728  0.04906009 -0.01503711 -0.0791343 ]
# iteration 494 error: [ 0.11309426  0.04903276 -0.01502873 -0.07909023]
# iteration 495 error: [ 0.11303127  0.04900545 -0.01502036 -0.07904618]
# iteration 496 error: [ 0.11296832  0.04897816 -0.015012   -0.07900216]
# iteration 497 error: [ 0.1129054   0.04895088 -0.01500364 -0.07895816]
# iteration 498 error: [ 0.11284252  0.04892362 -0.01499528 -0.07891418]
# iteration 499 error: [ 0.11277968  0.04889637 -0.01498693 -0.07887023]
# iteration 500 error: [ 0.11271687  0.04886914 -0.01497858 -0.07882631]
# iteration 501 error: [ 0.11265409  0.04884193 -0.01497024 -0.07878241]
# iteration 502 error: [ 0.11259135  0.04881472 -0.0149619  -0.07873853]
# iteration 503 error: [ 0.11252864  0.04878754 -0.01495357 -0.07869468]
# iteration 504 error: [ 0.11246597  0.04876037 -0.01494524 -0.07865085]
# iteration 505 error: [ 0.11240334  0.04873321 -0.01493692 -0.07860705]
# iteration 506 error: [ 0.11234074  0.04870607 -0.0149286  -0.07856327]
# iteration 507 error: [ 0.11227817  0.04867894 -0.01492029 -0.07851951]
# iteration 508 error: [ 0.11221564  0.04865183 -0.01491198 -0.07847578]
# iteration 509 error: [ 0.11215314  0.04862474 -0.01490367 -0.07843208]
# iteration 510 error: [ 0.11209068  0.04859765 -0.01489537 -0.0783884 ]
# iteration 511 error: [ 0.11202825  0.04857059 -0.01488707 -0.07834474]
# iteration 512 error: [ 0.11196586  0.04854354 -0.01487878 -0.07830111]
# iteration 513 error: [ 0.1119035  0.0485165 -0.0148705 -0.0782575]
# iteration 514 error: [ 0.11184118  0.04848948 -0.01486222 -0.07821391]
# iteration 515 error: [ 0.11177889  0.04846248 -0.01485394 -0.07817035]
# iteration 516 error: [ 0.11171664  0.04843549 -0.01484567 -0.07812682]
# iteration 517 error: [ 0.11165442  0.04840851 -0.0148374  -0.07808331]
# iteration 518 error: [ 0.11159223  0.04838155 -0.01482913 -0.07803982]
# iteration 519 error: [ 0.11153009  0.04835461 -0.01482088 -0.07799636]
# iteration 520 error: [ 0.11146797  0.04832767 -0.01481262 -0.07795292]
# iteration 521 error: [ 0.11140589  0.04830076 -0.01480437 -0.0779095 ]
# iteration 522 error: [ 0.11134384  0.04827386 -0.01479613 -0.07786611]
# iteration 523 error: [ 0.11128183  0.04824697 -0.01478789 -0.07782275]
# iteration 524 error: [ 0.11121986  0.0482201  -0.01477965 -0.0777794 ]
# iteration 525 error: [ 0.11115791  0.04819325 -0.01477142 -0.07773609]
# iteration 526 error: [ 0.11109601  0.04816641 -0.01476319 -0.07769279]
# iteration 527 error: [ 0.11103413  0.04813958 -0.01475497 -0.07764952]
# iteration 528 error: [ 0.11097229  0.04811277 -0.01474675 -0.07760628]
# iteration 529 error: [ 0.11091049  0.04808598 -0.01473854 -0.07756305]
# iteration 530 error: [ 0.11084872  0.0480592  -0.01473033 -0.07751986]
# iteration 531 error: [ 0.11078699  0.04803243 -0.01472213 -0.07747668]
# iteration 532 error: [ 0.11072528  0.04800568 -0.01471393 -0.07743353]
# iteration 533 error: [ 0.11066362  0.04797894 -0.01470573 -0.07739041]
# iteration 534 error: [ 0.11060199  0.04795222 -0.01469754 -0.07734731]
# iteration 535 error: [ 0.11054039  0.04792551 -0.01468936 -0.07730423]
# iteration 536 error: [ 0.11047882  0.04789882 -0.01468118 -0.07726118]
# iteration 537 error: [ 0.11041729  0.04787215 -0.014673   -0.07721815]
# iteration 538 error: [ 0.1103558   0.04784549 -0.01466483 -0.07717514]
# iteration 539 error: [ 0.11029434  0.04781884 -0.01465666 -0.07713216]
# iteration 540 error: [ 0.11023291  0.04779221 -0.0146485  -0.0770892 ]
# iteration 541 error: [ 0.11017152  0.04776559 -0.01464034 -0.07704627]
# iteration 542 error: [ 0.11011016  0.04773899 -0.01463219 -0.07700336]
# iteration 543 error: [ 0.11004884  0.0477124  -0.01462404 -0.07696047]
# iteration 544 error: [ 0.10998755  0.04768583 -0.01461589 -0.07691761]
# iteration 545 error: [ 0.10992629  0.04765927 -0.01460775 -0.07687477]
# iteration 546 error: [ 0.10986507  0.04763273 -0.01459962 -0.07683196]
# iteration 547 error: [ 0.10980388  0.0476062  -0.01459149 -0.07678917]
# iteration 548 error: [ 0.10974273  0.04757968 -0.01458336 -0.0767464 ]
# iteration 549 error: [ 0.10968161  0.04755319 -0.01457524 -0.07670366]
# iteration 550 error: [ 0.10962052  0.0475267  -0.01456712 -0.07666094]
# iteration 551 error: [ 0.10955947  0.04750023 -0.01455901 -0.07661825]
# iteration 552 error: [ 0.10949845  0.04747378 -0.0145509  -0.07657557]
# iteration 553 error: [ 0.10943747  0.04744734 -0.01454279 -0.07653293]
# iteration 554 error: [ 0.10937652  0.04742091 -0.01453469 -0.0764903 ]
# iteration 555 error: [ 0.10931561  0.0473945  -0.0145266  -0.0764477 ]
# iteration 556 error: [ 0.10925472  0.04736811 -0.01451851 -0.07640513]
# iteration 557 error: [ 0.10919388  0.04734173 -0.01451042 -0.07636257]
# iteration 558 error: [ 0.10913306  0.04731536 -0.01450234 -0.07632005]
# iteration 559 error: [ 0.10907228  0.04728901 -0.01449427 -0.07627754]
# iteration 560 error: [ 0.10901154  0.04726267 -0.01448619 -0.07623506]
# iteration 561 error: [ 0.10895082  0.04723635 -0.01447813 -0.0761926 ]
# iteration 562 error: [ 0.10889015  0.04721004 -0.01447006 -0.07615017]
# iteration 563 error: [ 0.1088295   0.04718375 -0.014462   -0.07610776]
# iteration 564 error: [ 0.10876889  0.04715747 -0.01445395 -0.07606537]
# iteration 565 error: [ 0.10870831  0.04713121 -0.0144459  -0.07602301]
# iteration 566 error: [ 0.10864777  0.04710496 -0.01443785 -0.07598067]
# iteration 567 error: [ 0.10858726  0.04707872 -0.01442981 -0.07593835]
# iteration 568 error: [ 0.10852678  0.0470525  -0.01442178 -0.07589606]
# iteration 569 error: [ 0.10846634  0.0470263  -0.01441374 -0.07585379]
# iteration 570 error: [ 0.10840593  0.04700011 -0.01440572 -0.07581154]
# iteration 571 error: [ 0.10834556  0.04697393 -0.01439769 -0.07576932]
# iteration 572 error: [ 0.10828522  0.04694777 -0.01438968 -0.07572712]
# iteration 573 error: [ 0.10822491  0.04692162 -0.01438166 -0.07568495]
# iteration 574 error: [ 0.10816464  0.04689549 -0.01437365 -0.07564279]
# iteration 575 error: [ 0.10810439  0.04686937 -0.01436565 -0.07560067]
# iteration 576 error: [ 0.10804419  0.04684327 -0.01435765 -0.07555856]
# iteration 577 error: [ 0.10798401  0.04681718 -0.01434965 -0.07551648]
# iteration 578 error: [ 0.10792387  0.04679111 -0.01434166 -0.07547442]
# iteration 579 error: [ 0.10786377  0.04676505 -0.01433367 -0.07543239]
# iteration 580 error: [ 0.10780369  0.046739   -0.01432569 -0.07539038]
# iteration 581 error: [ 0.10774366  0.04671297 -0.01431771 -0.07534839]
# iteration 582 error: [ 0.10768365  0.04668696 -0.01430973 -0.07530643]
# iteration 583 error: [ 0.10762368  0.04666096 -0.01430177 -0.07526449]
# iteration 584 error: [ 0.10756374  0.04663497 -0.0142938  -0.07522257]
# iteration 585 error: [ 0.10750383  0.046609   -0.01428584 -0.07518067]
# iteration 586 error: [ 0.10744396  0.04658304 -0.01427788 -0.0751388 ]
# iteration 587 error: [ 0.10738412  0.04655709 -0.01426993 -0.07509696]
# iteration 588 error: [ 0.10732431  0.04653117 -0.01426198 -0.07505513]
# iteration 589 error: [ 0.10726454  0.04650525 -0.01425404 -0.07501333]
# iteration 590 error: [ 0.1072048   0.04647935 -0.0142461  -0.07497155]
# iteration 591 error: [ 0.1071451   0.04645346 -0.01423817 -0.0749298 ]
# iteration 592 error: [ 0.10708542  0.04642759 -0.01423024 -0.07488807]
# iteration 593 error: [ 0.10702578  0.04640174 -0.01422231 -0.07484636]
# iteration 594 error: [ 0.10696618  0.04637589 -0.01421439 -0.07480468]
# iteration 595 error: [ 0.1069066   0.04635006 -0.01420648 -0.07476302]
# iteration 596 error: [ 0.10684706  0.04632425 -0.01419856 -0.07472138]
# iteration 597 error: [ 0.10678756  0.04629845 -0.01419066 -0.07467976]
# iteration 598 error: [ 0.10672808  0.04627267 -0.01418275 -0.07463817]
# iteration 599 error: [ 0.10666864  0.04624689 -0.01417485 -0.0745966 ]
# iteration 600 error: [ 0.10660924  0.04622114 -0.01416696 -0.07455506]
# iteration 601 error: [ 0.10654986  0.0461954  -0.01415907 -0.07451353]
# iteration 602 error: [ 0.10649052  0.04616967 -0.01415118 -0.07447204]
# iteration 603 error: [ 0.10643121  0.04614395 -0.0141433  -0.07443056]
# iteration 604 error: [ 0.10637194  0.04611826 -0.01413543 -0.07438911]
# iteration 605 error: [ 0.10631269  0.04609257 -0.01412755 -0.07434768]
# iteration 606 error: [ 0.10625349  0.0460669  -0.01411968 -0.07430627]
# iteration 607 error: [ 0.10619431  0.04604124 -0.01411182 -0.07426489]
# iteration 608 error: [ 0.10613517  0.0460156  -0.01410396 -0.07422353]
# iteration 609 error: [ 0.10607606  0.04598997 -0.01409611 -0.07418219]
# iteration 610 error: [ 0.10601698  0.04596436 -0.01408826 -0.07414087]
# iteration 611 error: [ 0.10595793  0.04593876 -0.01408041 -0.07409958]
# iteration 612 error: [ 0.10589892  0.04591318 -0.01407257 -0.07405831]
# iteration 613 error: [ 0.10583994  0.04588761 -0.01406473 -0.07401707]
# iteration 614 error: [ 0.105781    0.04586205 -0.0140569  -0.07397584]
# iteration 615 error: [ 0.10572208  0.04583651 -0.01404907 -0.07393465]
# iteration 616 error: [ 0.1056632   0.04581098 -0.01404124 -0.07389347]
# iteration 617 error: [ 0.10560436  0.04578547 -0.01403342 -0.07385231]
# iteration 618 error: [ 0.10554554  0.04575997 -0.01402561 -0.07381118]
# iteration 619 error: [ 0.10548676  0.04573448 -0.0140178  -0.07377008]
# iteration 620 error: [ 0.10542801  0.04570901 -0.01400999 -0.07372899]
# iteration 621 error: [ 0.10536929  0.04568355 -0.01400219 -0.07368793]
# iteration 622 error: [ 0.10531061  0.04565811 -0.01399439 -0.07364689]
# iteration 623 error: [ 0.10525196  0.04563268 -0.0139866  -0.07360587]
# iteration 624 error: [ 0.10519334  0.04560727 -0.01397881 -0.07356488]
# iteration 625 error: [ 0.10513476  0.04558187 -0.01397102 -0.07352391]
# iteration 626 error: [ 0.1050762   0.04555648 -0.01396324 -0.07348296]
# iteration 627 error: [ 0.10501768  0.04553111 -0.01395546 -0.07344204]
# iteration 628 error: [ 0.10495919  0.04550575 -0.01394769 -0.07340113]
# iteration 629 error: [ 0.10490074  0.04548041 -0.01393992 -0.07336025]
# iteration 630 error: [ 0.10484232  0.04545508 -0.01393216 -0.0733194 ]
# iteration 631 error: [ 0.10478393  0.04542976 -0.0139244  -0.07327856]
# iteration 632 error: [ 0.10472557  0.04540446 -0.01391664 -0.07323775]
# iteration 633 error: [ 0.10466724  0.04537917 -0.01390889 -0.07319696]
# iteration 634 error: [ 0.10460895  0.0453539  -0.01390115 -0.0731562 ]
# iteration 635 error: [ 0.10455069  0.04532864 -0.01389341 -0.07311545]
# iteration 636 error: [ 0.10449246  0.0453034  -0.01388567 -0.07307473]
# iteration 637 error: [ 0.10443427  0.04527817 -0.01387793 -0.07303404]
# iteration 638 error: [ 0.1043761   0.04525295 -0.01387021 -0.07299336]
# iteration 639 error: [ 0.10431797  0.04522775 -0.01386248 -0.07295271]
# iteration 640 error: [ 0.10425987  0.04520256 -0.01385476 -0.07291208]
# iteration 641 error: [ 0.10420181  0.04517738 -0.01384704 -0.07287147]
# iteration 642 error: [ 0.10414378  0.04515222 -0.01383933 -0.07283089]
# iteration 643 error: [ 0.10408577  0.04512707 -0.01383162 -0.07279032]
# iteration 644 error: [ 0.10402781  0.04510194 -0.01382392 -0.07274978]
# iteration 645 error: [ 0.10396987  0.04507682 -0.01381622 -0.07270927]
# iteration 646 error: [ 0.10391196  0.04505172 -0.01380853 -0.07266877]
# iteration 647 error: [ 0.10385409  0.04502663 -0.01380084 -0.0726283 ]
# iteration 648 error: [ 0.10379625  0.04500155 -0.01379315 -0.07258785]
# iteration 649 error: [ 0.10373844  0.04497649 -0.01378547 -0.07254743]
# iteration 650 error: [ 0.10368067  0.04495144 -0.01377779 -0.07250702]
# iteration 651 error: [ 0.10362293  0.0449264  -0.01377012 -0.07246664]
# iteration 652 error: [ 0.10356521  0.04490138 -0.01376245 -0.07242628]
# iteration 653 error: [ 0.10350754  0.04487638 -0.01375478 -0.07238594]
# iteration 654 error: [ 0.10344989  0.04485138 -0.01374712 -0.07234563]
# iteration 655 error: [ 0.10339227  0.0448264  -0.01373947 -0.07230534]
# iteration 656 error: [ 0.10333469  0.04480144 -0.01373182 -0.07226507]
# iteration 657 error: [ 0.10327714  0.04477649 -0.01372417 -0.07222482]
# iteration 658 error: [ 0.10321962  0.04475155 -0.01371652 -0.0721846 ]
# iteration 659 error: [ 0.10316214  0.04472663 -0.01370889 -0.0721444 ]
# iteration 660 error: [ 0.10310468  0.04470172 -0.01370125 -0.07210422]
# iteration 661 error: [ 0.10304726  0.04467682 -0.01369362 -0.07206406]
# iteration 662 error: [ 0.10298987  0.04465194 -0.01368599 -0.07202392]
# iteration 663 error: [ 0.10293251  0.04462707 -0.01367837 -0.07198381]
# iteration 664 error: [ 0.10287518  0.04460221 -0.01367075 -0.07194372]
# iteration 665 error: [ 0.10281789  0.04457737 -0.01366314 -0.07190365]
# iteration 666 error: [ 0.10276063  0.04455255 -0.01365553 -0.07186361]
# iteration 667 error: [ 0.10270339  0.04452773 -0.01364792 -0.07182358]
# iteration 668 error: [ 0.1026462   0.04450294 -0.01364032 -0.07178358]
# iteration 669 error: [ 0.10258903  0.04447815 -0.01363273 -0.0717436 ]
# iteration 670 error: [ 0.10253189  0.04445338 -0.01362513 -0.07170365]
# iteration 671 error: [ 0.10247479  0.04442862 -0.01361755 -0.07166371]
# iteration 672 error: [ 0.10241772  0.04440388 -0.01360996 -0.0716238 ]
# iteration 673 error: [ 0.10236068  0.04437915 -0.01360238 -0.07158391]
# iteration 674 error: [ 0.10230367  0.04435443 -0.01359481 -0.07154404]
# iteration 675 error: [ 0.10224669  0.04432973 -0.01358723 -0.0715042 ]
# iteration 676 error: [ 0.10218975  0.04430504 -0.01357967 -0.07146438]
# iteration 677 error: [ 0.10213284  0.04428037 -0.0135721  -0.07142457]
# ...
# iteration 776 error: [ 0.09665254  0.04190435 -0.01284385 -0.06759204]
# iteration 777 error: [ 0.09659871  0.04188101 -0.01283669 -0.06755439]
# iteration 778 error: [ 0.09654491  0.04185768 -0.01282954 -0.06751677]
# iteration 779 error: [ 0.09649114  0.04183437 -0.0128224  -0.06747917]
# iteration 780 error: [ 0.0964374   0.04181107 -0.01281526 -0.06744158]
# iteration 781 error: [ 0.09638369  0.04178779 -0.01280812 -0.06740402]
# iteration 782 error: [ 0.09633001  0.04176451 -0.01280099 -0.06736648]
# iteration 783 error: [ 0.09627636  0.04174125 -0.01279386 -0.06732897]
# iteration 784 error: [ 0.09622274  0.041718   -0.01278673 -0.06729147]
# iteration 785 error: [ 0.09616915  0.04169477 -0.01277961 -0.06725399]
# iteration 786 error: [ 0.09611559  0.04167155 -0.01277249 -0.06721653]
# iteration 787 error: [ 0.09606206  0.04164834 -0.01276538 -0.0671791 ]
# iteration 788 error: [ 0.09600856  0.04162515 -0.01275827 -0.06714169]
# iteration 789 error: [ 0.09595509  0.04160196 -0.01275116 -0.06710429]
# iteration 790 error: [ 0.09590165  0.04157879 -0.01274406 -0.06706692]
# iteration 791 error: [ 0.09584824  0.04155564 -0.01273696 -0.06702957]
# iteration 792 error: [ 0.09579486  0.04153249 -0.01272987 -0.06699224]
# iteration 793 error: [ 0.09574151  0.04150936 -0.01272278 -0.06695493]
# iteration 794 error: [ 0.09568818  0.04148624 -0.0127157  -0.06691764]
# iteration 795 error: [ 0.09563489  0.04146314 -0.01270861 -0.06688037]
# iteration 796 error: [ 0.09558163  0.04144005 -0.01270154 -0.06684312]
# iteration 797 error: [ 0.0955284   0.04141697 -0.01269446 -0.06680589]
# iteration 798 error: [ 0.09547519  0.0413939  -0.01268739 -0.06676869]
# iteration 799 error: [ 0.09542202  0.04137085 -0.01268033 -0.0667315 ]
# iteration 800 error: [ 0.09536888  0.04134781 -0.01267326 -0.06669434]
# iteration 801 error: [ 0.09531576  0.04132478 -0.01266621 -0.06665719]
# iteration 802 error: [ 0.09526268  0.04130176 -0.01265915 -0.06662007]
# iteration 803 error: [ 0.09520962  0.04127876 -0.0126521  -0.06658296]
# iteration 804 error: [ 0.0951566   0.04125577 -0.01264506 -0.06654588]
# iteration 805 error: [ 0.0951036   0.04123279 -0.01263801 -0.06650882]
# iteration 806 error: [ 0.09505064  0.04120983 -0.01263097 -0.06647178]
# iteration 807 error: [ 0.0949977   0.04118688 -0.01262394 -0.06643476]
# iteration 808 error: [ 0.09494479  0.04116394 -0.01261691 -0.06639776]
# iteration 809 error: [ 0.09489191  0.04114102 -0.01260988 -0.06636078]
# iteration 810 error: [ 0.09483907  0.0411181  -0.01260286 -0.06632382]
# iteration 811 error: [ 0.09478625  0.0410952  -0.01259584 -0.06628688]
# iteration 812 error: [ 0.09473346  0.04107232 -0.01258883 -0.06624997]
# iteration 813 error: [ 0.0946807   0.04104944 -0.01258181 -0.06621307]
# iteration 814 error: [ 0.09462797  0.04102658 -0.01257481 -0.06617619]
# iteration 815 error: [ 0.09457526  0.04100373 -0.0125678  -0.06613934]
# iteration 816 error: [ 0.09452259  0.04098089 -0.0125608  -0.0661025 ]
# iteration 817 error: [ 0.09446995  0.04095807 -0.01255381 -0.06606569]
# iteration 818 error: [ 0.09441733  0.04093526 -0.01254682 -0.06602889]
# iteration 819 error: [ 0.09436475  0.04091246 -0.01253983 -0.06599212]
# iteration 820 error: [ 0.0943122   0.04088968 -0.01253285 -0.06595537]
# iteration 821 error: [ 0.09425967  0.0408669  -0.01252587 -0.06591863]
# iteration 822 error: [ 0.09420717  0.04084414 -0.01251889 -0.06588192]
# iteration 823 error: [ 0.09415471  0.04082139 -0.01251192 -0.06584523]
# iteration 824 error: [ 0.09410227  0.04079866 -0.01250495 -0.06580856]
# iteration 825 error: [ 0.09404986  0.04077594 -0.01249798 -0.06577191]
# iteration 826 error: [ 0.09399748  0.04075323 -0.01249102 -0.06573528]
# iteration 827 error: [ 0.09394513  0.04073053 -0.01248407 -0.06569867]
# iteration 828 error: [ 0.09389281  0.04070785 -0.01247711 -0.06566208]
# iteration 829 error: [ 0.09384052  0.04068518 -0.01247017 -0.06562551]
# iteration 830 error: [ 0.09378825  0.04066252 -0.01246322 -0.06558896]
# iteration 831 error: [ 0.09373602  0.04063987 -0.01245628 -0.06555243]
# iteration 832 error: [ 0.09368381  0.04061724 -0.01244934 -0.06551592]
# iteration 833 error: [ 0.09363164  0.04059462 -0.01244241 -0.06547943]
# iteration 834 error: [ 0.09357949  0.04057201 -0.01243548 -0.06544296]
# iteration 835 error: [ 0.09352737  0.04054941 -0.01242855 -0.06540652]
# iteration 836 error: [ 0.09347529  0.04052683 -0.01242163 -0.06537009]
# iteration 837 error: [ 0.09342323  0.04050426 -0.01241471 -0.06533368]
# iteration 838 error: [ 0.0933712  0.0404817 -0.0124078 -0.0652973]
# iteration 839 error: [ 0.09331919  0.04045915 -0.01240089 -0.06526093]
# iteration 840 error: [ 0.09326722  0.04043662 -0.01239398 -0.06522458]
# iteration 841 error: [ 0.09321528  0.0404141  -0.01238708 -0.06518826]
# iteration 842 error: [ 0.09316336  0.04039159 -0.01238018 -0.06515195]
# iteration 843 error: [ 0.09311148  0.0403691  -0.01237329 -0.06511567]
# iteration 844 error: [ 0.09305962  0.04034661 -0.01236639 -0.0650794 ]
# iteration 845 error: [ 0.09300779  0.04032414 -0.01235951 -0.06504316]
# iteration 846 error: [ 0.09295599  0.04030168 -0.01235262 -0.06500693]
# iteration 847 error: [ 0.09290422  0.04027924 -0.01234574 -0.06497073]
# iteration 848 error: [ 0.09285248  0.04025681 -0.01233887 -0.06493454]
# iteration 849 error: [ 0.09280077  0.04023439 -0.012332   -0.06489838]
# iteration 850 error: [ 0.09274908  0.04021198 -0.01232513 -0.06486223]
# iteration 851 error: [ 0.09269743  0.04018958 -0.01231826 -0.06482611]
# iteration 852 error: [ 0.0926458   0.0401672  -0.0123114  -0.06479001]
# iteration 853 error: [ 0.09259421  0.04014483 -0.01230455 -0.06475392]
# iteration 854 error: [ 0.09254264  0.04012247 -0.01229769 -0.06471786]
# iteration 855 error: [ 0.0924911   0.04010013 -0.01229085 -0.06468182]
# iteration 856 error: [ 0.09243959  0.04007779 -0.012284   -0.06464579]
# iteration 857 error: [ 0.0923881   0.04005547 -0.01227716 -0.06460979]
# iteration 858 error: [ 0.09233665  0.04003316 -0.01227032 -0.06457381]
# iteration 859 error: [ 0.09228522  0.04001087 -0.01226349 -0.06453784]
# iteration 860 error: [ 0.09223383  0.03998858 -0.01225666 -0.0645019 ]
# iteration 861 error: [ 0.09218246  0.03996631 -0.01224983 -0.06446598]
# iteration 862 error: [ 0.09213112  0.03994405 -0.01224301 -0.06443007]
# iteration 863 error: [ 0.09207981  0.03992181 -0.01223619 -0.06439419]
# iteration 864 error: [ 0.09202853  0.03989957 -0.01222938 -0.06435833]
# iteration 865 error: [ 0.09197727  0.03987735 -0.01222256 -0.06432248]
# iteration 866 error: [ 0.09192605  0.03985514 -0.01221576 -0.06428666]
# iteration 867 error: [ 0.09187485  0.03983295 -0.01220895 -0.06425086]
# iteration 868 error: [ 0.09182368  0.03981076 -0.01220215 -0.06421507]
# iteration 869 error: [ 0.09177254  0.03978859 -0.01219536 -0.06417931]
# iteration 870 error: [ 0.09172143  0.03976643 -0.01218857 -0.06414356]
# iteration 871 error: [ 0.09167035  0.03974428 -0.01218178 -0.06410784]
# iteration 872 error: [ 0.09161929  0.03972215 -0.01217499 -0.06407214]
# iteration 873 error: [ 0.09156827  0.03970003 -0.01216821 -0.06403645]
# iteration 874 error: [ 0.09151727  0.03967792 -0.01216144 -0.06400079]
# iteration 875 error: [ 0.0914663   0.03965582 -0.01215466 -0.06396514]
# iteration 876 error: [ 0.09141536  0.03963373 -0.01214789 -0.06392952]
# iteration 877 error: [ 0.09136445  0.03961166 -0.01214113 -0.06389392]
# iteration 878 error: [ 0.09131356  0.0395896  -0.01213437 -0.06385833]
# iteration 879 error: [ 0.09126271  0.03956755 -0.01212761 -0.06382277]
# iteration 880 error: [ 0.09121188  0.03954551 -0.01212085 -0.06378722]
# iteration 881 error: [ 0.09116108  0.03952349 -0.0121141  -0.0637517 ]
# iteration 882 error: [ 0.09111031  0.03950148 -0.01210736 -0.06371619]
# iteration 883 error: [ 0.09105957  0.03947948 -0.01210061 -0.0636807 ]
# iteration 884 error: [ 0.09100885  0.03945749 -0.01209387 -0.06364524]
# iteration 885 error: [ 0.09095817  0.03943551 -0.01208714 -0.06360979]
# iteration 886 error: [ 0.09090751  0.03941355 -0.01208041 -0.06357437]
# iteration 887 error: [ 0.09085688  0.0393916  -0.01207368 -0.06353896]
# iteration 888 error: [ 0.09080628  0.03936966 -0.01206696 -0.06350357]
# iteration 889 error: [ 0.09075571  0.03934774 -0.01206023 -0.06346821]
# iteration 890 error: [ 0.09070516  0.03932582 -0.01205352 -0.06343286]
# iteration 891 error: [ 0.09065464  0.03930392 -0.0120468  -0.06339753]
# iteration 892 error: [ 0.09060416  0.03928203 -0.0120401  -0.06336222]
# iteration 893 error: [ 0.0905537   0.03926015 -0.01203339 -0.06332693]
# iteration 894 error: [ 0.09050326  0.03923829 -0.01202669 -0.06329166]
# iteration 895 error: [ 0.09045286  0.03921643 -0.01201999 -0.06325641]
# iteration 896 error: [ 0.09040248  0.03919459 -0.0120133  -0.06322118]
# iteration 897 error: [ 0.09035213  0.03917276 -0.01200661 -0.06318597]
# iteration 898 error: [ 0.09030181  0.03915095 -0.01199992 -0.06315078]
# iteration 899 error: [ 0.09025152  0.03912914 -0.01199324 -0.06311561]
# iteration 900 error: [ 0.09020126  0.03910735 -0.01198656 -0.06308046]
# iteration 901 error: [ 0.09015102  0.03908557 -0.01197988 -0.06304533]
# iteration 902 error: [ 0.09010081  0.0390638  -0.01197321 -0.06301022]
# iteration 903 error: [ 0.09005063  0.03904205 -0.01196654 -0.06297513]
# iteration 904 error: [ 0.09000048  0.0390203  -0.01195988 -0.06294005]
# iteration 905 error: [ 0.08995036  0.03899857 -0.01195321 -0.062905  ]
# iteration 906 error: [ 0.08990026  0.03897685 -0.01194656 -0.06286997]
# iteration 907 error: [ 0.08985019  0.03895514 -0.0119399  -0.06283495]
# iteration 908 error: [ 0.08980015  0.03893345 -0.01193325 -0.06279996]
# iteration 909 error: [ 0.08975014  0.03891177 -0.01192661 -0.06276498]
# iteration 910 error: [ 0.08970015  0.03889009 -0.01191997 -0.06273002]
# iteration 911 error: [ 0.0896502   0.03886843 -0.01191333 -0.06269509]
# iteration 912 error: [ 0.08960027  0.03884679 -0.01190669 -0.06266017]
# iteration 913 error: [ 0.08955037  0.03882515 -0.01190006 -0.06262527]
# iteration 914 error: [ 0.08950049  0.03880353 -0.01189343 -0.0625904 ]
# iteration 915 error: [ 0.08945065  0.03878192 -0.01188681 -0.06255554]
# iteration 916 error: [ 0.08940083  0.03876032 -0.01188019 -0.0625207 ]
# iteration 917 error: [ 0.08935104  0.03873873 -0.01187357 -0.06248588]
# iteration 918 error: [ 0.08930127  0.03871716 -0.01186696 -0.06245108]
# iteration 919 error: [ 0.08925154  0.03869559 -0.01186035 -0.0624163 ]
# iteration 920 error: [ 0.08920183  0.03867404 -0.01185375 -0.06238153]
# iteration 921 error: [ 0.08915215  0.0386525  -0.01184714 -0.06234679]
# iteration 922 error: [ 0.0891025   0.03863098 -0.01184055 -0.06231207]
# iteration 923 error: [ 0.08905288  0.03860946 -0.01183395 -0.06227737]
# iteration 924 error: [ 0.08900328  0.03858796 -0.01182736 -0.06224268]
# iteration 925 error: [ 0.08895371  0.03856647 -0.01182077 -0.06220802]
# iteration 926 error: [ 0.08890417  0.03854499 -0.01181419 -0.06217337]
# iteration 927 error: [ 0.08885466  0.03852352 -0.01180761 -0.06213874]
# iteration 928 error: [ 0.08880517  0.03850207 -0.01180103 -0.06210414]
# iteration 929 error: [ 0.08875571  0.03848062 -0.01179446 -0.06206955]
# iteration 930 error: [ 0.08870628  0.03845919 -0.01178789 -0.06203498]
# iteration 931 error: [ 0.08865688  0.03843777 -0.01178133 -0.06200043]
# iteration 932 error: [ 0.0886075   0.03841637 -0.01177477 -0.0619659 ]
# iteration 933 error: [ 0.08855815  0.03839497 -0.01176821 -0.06193139]
# iteration 934 error: [ 0.08850883  0.03837359 -0.01176165 -0.0618969 ]
# iteration 935 error: [ 0.08845954  0.03835222 -0.0117551  -0.06186243]
# iteration 936 error: [ 0.08841027  0.03833086 -0.01174856 -0.06182797]
# iteration 937 error: [ 0.08836103  0.03830951 -0.01174201 -0.06179354]
# iteration 938 error: [ 0.08831182  0.03828817 -0.01173547 -0.06175912]
# iteration 939 error: [ 0.08826264  0.03826685 -0.01172894 -0.06172473]
# iteration 940 error: [ 0.08821348  0.03824554 -0.01172241 -0.06169035]
# iteration 941 error: [ 0.08816435  0.03822424 -0.01171588 -0.06165599]
# iteration 942 error: [ 0.08811525  0.03820295 -0.01170935 -0.06162165]
# iteration 943 error: [ 0.08806618  0.03818167 -0.01170283 -0.06158734]
# iteration 944 error: [ 0.08801713  0.03816041 -0.01169631 -0.06155304]
# iteration 945 error: [ 0.08796811  0.03813915 -0.0116898  -0.06151875]
# iteration 946 error: [ 0.08791912  0.03811791 -0.01168329 -0.06148449]
# iteration 947 error: [ 0.08787015  0.03809668 -0.01167678 -0.06145025]
# iteration 948 error: [ 0.08782121  0.03807547 -0.01167028 -0.06141603]
# iteration 949 error: [ 0.0877723   0.03805426 -0.01166378 -0.06138182]
# iteration 950 error: [ 0.08772342  0.03803307 -0.01165728 -0.06134764]
# iteration 951 error: [ 0.08767456  0.03801189 -0.01165079 -0.06131347]
# iteration 952 error: [ 0.08762573  0.03799072 -0.0116443  -0.06127932]
# iteration 953 error: [ 0.08757693  0.03796956 -0.01163782 -0.06124519]
# iteration 954 error: [ 0.08752816  0.03794841 -0.01163134 -0.06121108]
# iteration 955 error: [ 0.08747941  0.03792728 -0.01162486 -0.06117699]
# iteration 956 error: [ 0.08743069  0.03790615 -0.01161838 -0.06114292]
# iteration 957 error: [ 0.087382    0.03788504 -0.01161191 -0.06110887]
# iteration 958 error: [ 0.08733333  0.03786394 -0.01160545 -0.06107483]
# iteration 959 error: [ 0.08728469  0.03784285 -0.01159898 -0.06104082]
# iteration 960 error: [ 0.08723608  0.03782178 -0.01159252 -0.06100682]
# iteration 961 error: [ 0.0871875   0.03780071 -0.01158607 -0.06097285]
# iteration 962 error: [ 0.08713894  0.03777966 -0.01157961 -0.06093889]
# iteration 963 error: [ 0.08709041  0.03775862 -0.01157316 -0.06090495]
# iteration 964 error: [ 0.0870419   0.03773759 -0.01156672 -0.06087103]
# iteration 965 error: [ 0.08699343  0.03771657 -0.01156028 -0.06083713]
# iteration 966 error: [ 0.08694498  0.03769557 -0.01155384 -0.06080325]
# iteration 967 error: [ 0.08689656  0.03767458 -0.0115474  -0.06076938]
# iteration 968 error: [ 0.08684816  0.03765359 -0.01154097 -0.06073554]
# iteration 969 error: [ 0.08679979  0.03763262 -0.01153455 -0.06070171]
# iteration 970 error: [ 0.08675145  0.03761166 -0.01152812 -0.06066791]
# iteration 971 error: [ 0.08670313  0.03759072 -0.0115217  -0.06063412]
# iteration 972 error: [ 0.08665485  0.03756978 -0.01151528 -0.06060035]
# iteration 973 error: [ 0.08660659  0.03754886 -0.01150887 -0.0605666 ]
# iteration 974 error: [ 0.08655835  0.03752794 -0.01150246 -0.06053287]
# iteration 975 error: [ 0.08651014  0.03750704 -0.01149606 -0.06049916]
# iteration 976 error: [ 0.08646196  0.03748616 -0.01148965 -0.06046546]
# iteration 977 error: [ 0.08641381  0.03746528 -0.01148325 -0.06043179]
# iteration 978 error: [ 0.08636568  0.03744441 -0.01147686 -0.06039813]
# iteration 979 error: [ 0.08631758  0.03742356 -0.01147047 -0.06036449]
# iteration 980 error: [ 0.08626951  0.03740272 -0.01146408 -0.06033087]
# iteration 981 error: [ 0.08622146  0.03738188 -0.01145769 -0.06029727]
# iteration 982 error: [ 0.08617344  0.03736107 -0.01145131 -0.06026369]
# iteration 983 error: [ 0.08612545  0.03734026 -0.01144493 -0.06023013]
# iteration 984 error: [ 0.08607748  0.03731946 -0.01143856 -0.06019658]
# iteration 985 error: [ 0.08602954  0.03729868 -0.01143219 -0.06016306]
# iteration 986 error: [ 0.08598163  0.0372779  -0.01142582 -0.06012955]
# iteration 987 error: [ 0.08593375  0.03725714 -0.01141946 -0.06009606]
# iteration 988 error: [ 0.08588589  0.03723639 -0.0114131  -0.06006259]
# iteration 989 error: [ 0.08583805  0.03721566 -0.01140674 -0.06002914]
# iteration 990 error: [ 0.08579025  0.03719493 -0.01140039 -0.05999571]
# iteration 991 error: [ 0.08574247  0.03717421 -0.01139404 -0.0599623 ]
# iteration 992 error: [ 0.08569472  0.03715351 -0.0113877  -0.0599289 ]
# iteration 993 error: [ 0.08564699  0.03713282 -0.01138135 -0.05989552]
# iteration 994 error: [ 0.08559929  0.03711214 -0.01137501 -0.05986217]
# iteration 995 error: [ 0.08555162  0.03709147 -0.01136868 -0.05982883]
# iteration 996 error: [ 0.08550397  0.03707081 -0.01136235 -0.05979551]
# iteration 997 error: [ 0.08545635  0.03705016 -0.01135602 -0.0597622 ]
# iteration 998 error: [ 0.08540876  0.03702953 -0.0113497  -0.05972892]
# iteration 999 error: [ 0.08536119  0.03700891 -0.01134337 -0.05969566]
# Optimal weights (theta): [0.23028971 1.95167465]

# %%
# Gradient descent 

# input (1,2,3,4,5,7) x
# output (1,2,3,4,6,8) y

x = [1,2,3,4,5,7]
y = [1,2,3,4,6,8]

# plotting function 

import matplotlib.pyplot as plt


def display_graph(x, y):
    plt.plot(x, y)
    # naming the x axis
    plt.xlabel('x - axis')
    # naming the y axis
    plt.ylabel('y - axis')


display_graph(x, y)    



# gradient descent function 

def gradient_descent(x, y):
    
    w = 0
    b = 0

# 1. y ? f(x): wx + b


    for iteration in range (100):
        sum_ob_f = 0
        gradient_w_sum = 0
        gradient_b_sum = 0

        for i in range (len(x)):
            y_hat = w * x [i] + b 

    # ob_f =  (y - y^)^2 의 합
    #        ob_f = (y - y_hat) ** 2 
    #        sum_ob_f = ob_f

            #gradient_w = 0.5 * (y_hat - y [i]) * x [i]
            gradient_w = 0.5 * (y_hat - y [i]) * x [i]
            #gradient_w = 0.5 * (y [i] - y_hat ) * x [i]
            gradient_w_sum = gradient_w_sum +  gradient_w

            #gradient_b = 2 * (y[i] - y_hat)
            gradient_b = 2 * ( y_hat - y[i])
            gradient_b_sum = gradient_b_sum + gradient_b
        
        w = w - 0.001 * gradient_w_sum
        b = b - 0.001 * gradient_b_sum
        print (f"gradient : {w} y-intercept: {b}")

# 2. 기울기를 구해서 업데이트 
    



#      = (y - (wx + b ) ^ 2 의 합 
        
# 기울기는 ob_f의 미분값

# w = w - learning_rate * gradient 

# 반복해서 이 과정을 수행한다. 10


# 최적화된 w, b

    return w, b

w, b  = gradient_descent(x, y)

print (f"weight: {w}, bias: {b}")

def line_graph (g, b):
    x = np.linspace(0, 10, 10)
    y = g * x + b
    plt.plot(x, y)


line_graph (w, b)
# Out:
# gradient : 0.058 y-intercept: 0.048
# gradient : 0.112456 y-intercept: 0.09287200000000001
# gradient : 0.163586696 y-intercept: 0.134809472
# gradient : 0.211597283616 y-intercept: 0.173993943712
# gradient : 0.256680291487136 y-intercept: 0.210595735908352
# gradient : 0.29901636323481307 y-intercept: 0.2447746542520178
# gradient : 0.33877499114983056 y-intercept: 0.2766806384186618
# gradient : 0.3761152045874341 y-intercept: 0.3064543711470453
# gradient : 0.41118621586627 y-intercept: 0.33422784969143365
# gradient : 0.44412802629461823 y-intercept: 0.36012492199702056
# gradient : 0.47507199478533085 y-intercept: 0.3842617897760931
# gradient : 0.5041413713689566 y-intercept: 0.4067474805282254
# gradient : 0.5314517977719604 y-intercept: 0.4276842904216526
# gradient : 0.5571117770931803 y-intercept: 0.4471681998346265
# gradient : 0.581223114486154 y-intercept: 0.4652892632445111
# gradient : 0.6038813306371844 y-intercept: 0.48213197504818617
# gradient : 0.6251760497185208 y-intercept: 0.49777561279957183
# gradient : 0.6451913633923624 y-intercept: 0.5122945592583621
# gradient : 0.6640061723441175 y-intercept: 0.5257586045579978
# gradient : 0.6816945067320854 y-intercept: 0.5382332297201606
# gradient : 0.6983258268550953 y-intercept: 0.549779872667307
# gradient : 0.7139653052592899 y-intercept: 0.5604561778136751
# gradient : 0.7286740914298564 y-intercept: 0.5703162302485022
# gradient : 0.7425095601427704 y-intercept: 0.5794107754626064
# gradient : 0.7555255444852577 y-intercept: 0.5877874255107732
# gradient : 0.7677725544914058 y-intercept: 0.5954908524472926
# gradient : 0.7792979822809325 y-intercept: 0.6025629698203032
# gradient : 0.7901462945343006 y-intercept: 0.6090431029620985
# gradient : 0.8003592130859339 y-intercept: 0.6149681487670441
# gradient : 0.8099758843690279 y-intercept: 0.6203727256060585
# gradient : 0.8190330384001718 y-intercept: 0.6252893139865485
# gradient : 0.8275651379495108 y-intercept: 0.6297483885291024
# gradient : 0.8356045185023161 y-intercept: 0.6337785417969747
# gradient : 0.843181519580429 y-intercept: 0.637406600481309
# gradient : 0.8503246079569523 y-intercept: 0.6406577344139944
# gradient : 0.8570604932646368 y-intercept: 0.6435555588509206
# gradient : 0.8634142364675156 y-intercept: 0.6461222304410655
# gradient : 0.869409351636353 y-intercept: 0.6483785372712021
# gradient : 0.8750679014412794 y-intercept: 0.6503439833519481
# gradient : 0.8804105867494615 y-intercept: 0.6520368678883084
# gradient : 0.8854568306917181 y-intercept: 0.6534743596566723
# gradient : 0.8902248575395254 y-intercept: 0.6546725667903567
# gradient : 0.8947317667127762 y-intercept: 0.6556466022571333
# gradient : 0.8989936022188834 y-intercept: 0.6564106452946856
# gradient : 0.9030254178052599 y-intercept: 0.6569779990535185
# gradient : 0.9068413380897977 y-intercept: 0.6573611446814448
# gradient : 0.9104546159176323 y-intercept: 0.6575717920693164
# gradient : 0.9138776861771529 y-intercept: 0.6576209274641087
# gradient : 0.9171222162938357 y-intercept: 0.6575188581427447
# gradient : 0.9201991536069861 y-intercept: 0.657275254328103
# gradient : 0.9231187698218137 y-intercept: 0.6568991885174583
# gradient : 0.9258907027173874 y-intercept: 0.656399172383089
# gradient : 0.9285239952798693 y-intercept: 0.6557831913949269
# gradient : 0.9310271324199719 y-intercept: 0.6550587373058735
# gradient : 0.9334080754237688 y-intercept: 0.6542328386317242
# gradient : 0.9356742942767838 y-intercept: 0.6533120892494977
# gradient : 0.9378327979926466 y-intercept: 0.6523026752303253
# gradient : 0.9398901630694955 y-intercept: 0.6512104000158849
# gradient : 0.941852560189707 y-intercept: 0.6500407080406365
# gradient : 0.9437257792713952 y-intercept: 0.6487987068958018
# gradient : 0.9455152529734289 y-intercept: 0.6474891881251108
# gradient : 0.9472260787494343 y-intercept: 0.6461166467367786
# gradient : 0.9488630395403592 y-intercept: 0.6446852995109621
# gradient : 0.95043062318964 y-intercept: 0.6431991021770548
# gradient : 0.9519330406598311 y-intercept: 0.641661765530586
# gradient : 0.9533742431246834 y-intercept: 0.6400767705551864
# gradient : 0.9547579380060929 y-intercept: 0.6384473826110381
# gradient : 0.9560876040210546 y-intercept: 0.6367766647474375
# gradient : 0.957366505299738 y-intercept: 0.6350674901935419
# gradient : 0.9585977046320227 y-intercept: 0.633322554078031
# gradient : 0.9597840758962991 y-intercept: 0.6315443844252856
# gradient : 0.9609283157210134 y-intercept: 0.629735352472745
# gradient : 0.9620329544263205 y-intercept: 0.6278976823513475
# gradient : 0.9631003662902871 y-intercept: 0.6260334601683731
# gradient : 0.96413277918134 y-intercept: 0.62414464252958
# gradient : 0.9651322835960849 y-intercept: 0.6222330645352461
# gradient : 0.9661008411392008 y-intercept: 0.6203004472825954
# gradient : 0.9670402924798538 y-intercept: 0.6183484049050794
# gradient : 0.9679523648169455 y-intercept: 0.6163784511771049
# gradient : 0.9688386788835162 y-intercept: 0.614392005711034
# gradient : 0.9697007555187519 y-intercept: 0.6123903997716269
# gradient : 0.9705400218342889 y-intercept: 0.6103748817315423
# gradient : 0.9713578169998589 y-intercept: 0.6083466221900551
# gradient : 0.9721553976717756 y-intercept: 0.6063067187757807
# gradient : 0.9729339430863096 y-intercept: 0.6042562006529132
# gradient : 0.9736945598386395 y-intercept: 0.6021960327492806
# gradient : 0.9744382863667882 y-intercept: 0.6001271197233891
# gradient : 0.9751660971587579 y-intercept: 0.5980503096865697
# gradient : 0.9758789066999503 y-intercept: 0.5959663976953455
# gradient : 0.9765775731769041 y-intercept: 0.5938761290282036
# gradient : 0.9772629019523948 y-intercept: 0.5917802022600814
# gradient : 0.9779356488260094 y-intercept: 0.5896792721470551
# gradient : 0.9785965230934393 y-intercept: 0.587573952332946
# gradient : 0.979246190416918 y-intercept: 0.5854648178888393
# gradient : 0.9798852755184609 y-intercept: 0.5833524076958289
# gradient : 0.9805143647068468 y-intercept: 0.5812372266806666
# gradient : 0.9811340082486034 y-intercept: 0.5791197479133973
# gradient : 0.9817447225926287 y-intercept: 0.577000414575498
# gradient : 0.9823469924574815 y-intercept: 0.5748796418065164
# gradient : 0.9829412727898208 y-intercept: 0.572757818436709
# weight: 0.9829412727898208, bias: 0.572757818436709

# %%
result
# Out:
# (-1.12, 0.0)

# %%
import numpy as np
np.square(2)
# Out:
# 4

# %%
import numpy as np

def gradient_descent(x, y, learning_rate, num_iterations):
    num_samples = x.shape[0]
    num_features = x.shape[1]
    theta = np.zeros(num_features + 1)  # Initializing weights with bias term

    # Adding a column of 1s for the bias term in the input data
    x = np.concatenate((np.ones((num_samples, 1)), x), axis=1)

    for iteration in range(num_iterations):
        error = np.dot(x, theta) - y
        gradient = 1 / num_samples * np.dot(x.T, error)
        theta -= learning_rate * gradient

    return theta

# Data preparation
x = np.array([[3], [4], [5], [6]])  # Input variable (only 1-dimensional for simplicity)
y = np.array([6, 8, 10, 12])  # Output variable

# Hyperparameter settings
learning_rate = 0.01
num_iterations = 1000

# Gradient descent execution
theta = gradient_descent(x, y, learning_rate, num_iterations)

print("Optimal weights (theta):", theta)
# Out:
# Optimal weights (theta): [0.23028971 1.95167465]

# %%
import numpy as np

def gradient_descent(x, y, learning_rate, num_iterations):
    num_samples = x.shape[0]
    num_features = x.shape[1]
    theta = np.zeros(num_features + 1)  # Initializing weights with bias term

    # Adding a column of 1s for the bias term in the input data
    x = np.concatenate((np.ones((num_samples, 1)), x), axis=1)

    for iteration in range(num_iterations):
        error = np.dot(x, theta) - y
        gradient = 1 / num_samples * np.dot(x.T, error)
        theta -= learning_rate * gradient

    return theta

# Data preparation
x = np.array([[1, 3], [1, 4], [1, 5], [1, 6]])  # Input variable (1-dimensional and 2-dimensional values)
y = np.array([6, 8, 10, 12])  # Output variable

# Hyperparameter settings
learning_rate = 0.01
num_iterations = 1000

# Gradient descent execution
theta = gradient_descent(x, y, learning_rate, num_iterations)

print("Optimal weights (theta):", theta)
# Out:
# Optimal weights (theta): [0.1326687  0.1326687  1.94418684]

# %%
import numpy as np

def gradient_descent(x, y, learning_rate, num_iterations):
    num_samples = x.shape[0]
    num_features = x.shape[1]
    theta = np.zeros(num_features + 1)  # Initializing weights with bias term

    # Adding a column of 1s for the bias term in the input data
    x = np.concatenate((np.ones((num_samples, 1)), x), axis=1)

    for iteration in range(num_iterations):
        error = np.dot(x, theta) - y
        gradient = 1 / num_samples * np.dot(x.T, error)
        theta -= learning_rate * gradient

    return theta

# Data preparation
x = np.array([[1, 3], [1, 4], [1, 5], [1, 6]])  # Input variable (1-dimensional and 2-dimensional values)
y = np.array([6, 8, 10, 12])  # Output variable

# Hyperparameter settings
learning_rate = 0.01
num_iterations = 1000

# Gradient descent execution
theta = gradient_descent(x, y, learning_rate, num_iterations)

print("Optimal weights (theta):", theta)
# Out:
# Optimal weights (theta): [0.1326687  0.1326687  1.94418684]

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descent(x, y, learning_rate, num_iterations):
    num_samples = x.shape[0]
    num_features = x.shape[1]
    theta = np.zeros(num_features + 1)  # Initializing weights with bias term

    # Adding a column of 1s for the bias term in the input data
    x = np.concatenate((np.ones((num_samples, 1)), x), axis=1)

    for iteration in range(num_iterations):
        error = np.dot(x, theta) - y
        gradient = 1 / num_samples * np.dot(x.T, error)
        theta -= learning_rate * gradient

    return theta

# Data preparation
x = np.array([[1, 3], [1, 4], [1, 5], [1, 6]])  # Input variable (1-dimensional and 2-dimensional values)
y = np.array([6, 8, 10, 12])  # Output variable

# Hyperparameter settings
learning_rate = 0.01
num_iterations = 1000

# Gradient descent execution
theta = gradient_descent(x, y, learning_rate, num_iterations)

# Plotting the data and regression line
plt.scatter(x[:, 1], y, color='blue', label='Data Points')
plt.xlabel('Input Feature')
plt.ylabel('Output Variable')

# Generating the regression line
x_line = np.linspace(np.min(x[:, 1]), np.max(x[:, 1]), 100)
y_line = theta[0] + theta[1] * x_line
plt.plot(x_line, y_line, color='red', label='Regression Line')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def gradient_descent(x, y, learning_rate, num_iterations):
    num_samples = x.shape[0]
    num_features = x.shape[1]
    theta = np.zeros(num_features + 1)  # Initializing weights with bias term

    # Adding a column of 1s for the bias term in the input data
    x = np.concatenate((np.ones((num_samples, 1)), x), axis=1)

    for iteration in range(num_iterations):
        error = np.dot(x, theta) - y
        gradient = 1 / num_samples * np.dot(x.T, error)
        theta -= learning_rate * gradient

    return theta

# Data preparation
x = np.array([[1, 3, 4], [1, 4, 6], [1, 5, 7], [1, 6, 9]])  # Input variable (3-dimensional values)
y = np.array([6, 8, 10, 12])  # Output variable

# Hyperparameter settings
learning_rate = 0.01
num_iterations = 1000

# Gradient descent execution
theta = gradient_descent(x, y, learning_rate, num_iterations)

# Creating a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting the data points
ax.scatter(x[:, 1], x[:, 2], y, color='blue', label='Data Points')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Output Variable')

# Generating the regression plane
x1_range = np.linspace(np.min(x[:, 1]), np.max(x[:, 1]), 10)
x2_range = np.linspace(np.min(x[:, 2]), np.max(x[:, 2]), 10)
x1_values, x2_values = np.meshgrid(x1_range, x2_range)
y_values = theta[0] + theta[1] * x1_values + theta[2] * x2_values
ax.plot_surface(x1_values, x2_values, y_values, alpha=0.5, color='red', label='Regression Plane')

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ff8906604ca0> in <cell line: 48>()
#      46 ax.plot_surface(x1_values, x2_values, y_values, alpha=0.5, color='red', label='Regression Plane')
#      47
# ---> 48 ax.legend()
#      49 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     316         if len(extra_args):
#     317             raise TypeError('legend only accepts two non-keyword arguments')
# --> 318         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     319         self.legend_._remove_method = self._remove_legend
#     320         return self.legend_
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     452                 "parameter will become keyword-only %(removal)s.",
#     453                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454         return func(*args, **kwargs)
#     455
#     456     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/legend.py in __init__(self, parent, handles, labels, loc, numpoints, markerscale, markerfirst, reverse, scatterpoints, scatteryoffsets, prop, fontsize, labelcolor, borderpad, labelspacing, handlelength, handleheight, handletextpad, borderaxespad, columnspacing, ncols, mode, fancybox, shadow, title, title_fontsize, framealpha, edgecolor, facecolor, bbox_to_anchor, bbox_transform, frameon, handler_map, title_fontproperties, alignment, ncol, draggable)
#     581
#     582         # init with null renderer
# --> 583         self._init_legend_box(handles, labels, markerfirst)
#     584
#     585         tmp = self._loc_used_default
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/legend.py in _init_legend_box(self, handles, labels, markerfirst)
#     865                 # Create the artist for the legend which represents the
#     866                 # original artist/handle.
# --> 867                 handle_list.append(handler.legend_artist(self, orig_handle,
#     868                                                          fontsize, handlebox))
#     869                 handles_and_labels.append((handlebox, textbox))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/legend_handler.py in legend_artist(self, legend, orig_handle, fontsize, handlebox)
#     128                  handlebox.width, handlebox.height,
#     129                  fontsize)
# --> 130         artists = self.create_artists(legend, orig_handle,
#     131                                       xdescent, ydescent, width, height,
#     132                                       fontsize, handlebox.get_transform())
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/legend_handler.py in create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans)
#     813         p = Rectangle(xy=(-xdescent, -ydescent),
#     814                       width=width, height=height)
# --> 815         self.update_prop(p, orig_handle, legend)
#     816         p.set_transform(trans)
#     817         return [p]
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/legend_handler.py in update_prop(self, legend_handle, orig_handle, legend)
#      87     def update_prop(self, legend_handle, orig_handle, legend):
#      88
# ---> 89         self._update_prop(legend_handle, orig_handle)
#      90
#      91         legend._set_artist_props(legend_handle)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/legend_handler.py in _update_prop(self, legend_handle, orig_handle)
#     793         # orig_handle is a PolyCollection and legend_handle is a Patch.
#     794         # Directly set Patch color attributes (must be RGBA tuples).
# --> 795         legend_handle._facecolor = first_color(orig_handle.get_facecolor())
#     796         legend_handle._edgecolor = first_color(orig_handle.get_edgecolor())
#     797         legend_handle._original_facecolor = orig_handle._original_facecolor
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/legend_handler.py in first_color(colors)
#     781     def _update_prop(self, legend_handle, orig_handle):
#     782         def first_color(colors):
# --> 783             if colors.size == 0:
#     784                 return (0, 0, 0, 0)
#     785             return tuple(colors[0])
#
# AttributeError: 'tuple' object has no attribute 'size'

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def gradient_descent(x, y, learning_rate, num_iterations):
    num_samples = x.shape[0]
    num_features = x.shape[1]
    theta = np.zeros(num_features + 1)  # Initializing weights with bias term

    # Adding a column of 1s for the bias term in the input data
    x = np.concatenate((np.ones((num_samples, 1)), x), axis=1)

    for iteration in range(num_iterations):
        error = np.dot(x, theta) - y
        gradient = 1 / num_samples * np.dot(x.T, error)
        theta -= learning_rate * gradient

    return theta

# Data preparation
x = np.array([[1, 3, 4], [1, 4, 6], [1, 5, 7], [1, 6, 9]])  # Input variable (3-dimensional values)
y = np.array([6, 8, 10, 12])  # Output variable

# Hyperparameter settings
learning_rate = 0.01
num_iterations = 1000

# Gradient descent execution
theta = gradient_descent(x, y, learning_rate, num_iterations)


print("Optimal weights (theta):", theta)

# Creating a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plotting the data points
ax.scatter(x[:, 1], x[:, 2], y, color='blue', label='Data Points')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Output Variable')

# Generating the regression plane
x1_range = np.linspace(np.min(x[:, 1]), np.max(x[:, 1]), 10)
x2_range = np.linspace(np.min(x[:, 2]), np.max(x[:, 2]), 10)
x1_values, x2_values = np.meshgrid(x1_range, x2_range)
y_values = theta[0] + theta[1] * x1_values + theta[2] * x2_values
ax.plot_surface(x1_values, x2_values, y_values, alpha=0.5, color='red', label='Regression Plane')

plt.show()
# Out:
# Optimal weights (theta): [0.25604537 0.25604537 0.82434013 0.73457817]
